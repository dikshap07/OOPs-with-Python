# %% [markdown]
# <a href="https://colab.research.google.com/github/dikshap07/OOPs-with-Python/blob/master/war_game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
 
suits = ['Hearts','Clubs','Spades','Diamonds']
 
ranks = ['Two','Three','Four','Five','Six','Seven','Eight','Nine','Ten','Jack','Queen','King','Ace']
 
values = {'Two': 2, 'Three': 3, 'Four': 4, 'Five': 5, 'Six' : 6 , 'Seven' :7, 'Eight': 8,'Nine':9,
          'Ten':10,'Jack':11, 'Queen': 12,'King': 13,'Ace':14 }

# %%
class Card():  
    
    
    def __init__(self,suit,rank):
        
        self.suit = suit
        self.rank = rank
        self.value = values[rank]
    
    #string method
    def __str__(self):
        
        return self.rank + ' of ' + self.suit

# %%
class Deck():

  def __init__(self):

    self.all_cards = []  #list of objects

    for suit in suits:

      for rank in ranks:
        #create card object

        created_card = Card(suit,rank)

        self.all_cards.append(created_card)


  def shuffle(self):   #method to shuffle the card

    random.shuffle(self.all_cards)



  def deal_one(self):

    return self.all_cards.pop()  #we want the last card from deck

# %%
#player class

#used to hold a player's current list of cards
#player should be able to add or remove cards from their hands
#player shoyld be able to add single or mulitple cards to their list of card objects
class Player():

  def __init__(self,name):

    self.name  = name
    self.all_cards = []

  def remove_one(self):

    return self.all_cards.pop(0)    #to remove card from beginning of the list

    

  def add_cards(self,new_cards):


    if type(new_cards) == type([]):

      self.all_cards.extend(new_cards)

    else:

      self.all_cards.append(new_cards)

  def __str__(self):
    return f'Player {self.name} has {len(self.all_cards)} cards.'

# %% [markdown]
# #GAME LOGIC

# %%
#create 2 new instances of the player class

player1_name = input('Enter the name of Player1: ')

player2_name = input('Enter the name of Player2: ')

player1 = Player(player1_name)
player2 = Player(player2_name)
newdeck = Deck()
newdeck.shuffle()

#splitting the deck among the two players - alternate card from deck goes to each player respectively

for i in range(0,len(newdeck.all_cards)-1,2):  

  player1.add_cards(newdeck.all_cards[i])
  player2.add_cards(newdeck.all_cards[i+1])



print(player1)
print(player2)


game_status = True
    
round_num = 0
while game_status == True:

  round_num +=1
  print(f"Round {round_num}")


  if len(player1.all_cards) == 0:

    print('Player 1 out of cards'+ player2.name + 'Wins!')
    game_status = False
    break
  
  if len(player2.all_cards) == 0:

    print('Player 2 out of cards' + player1.name + 'Wins!')
    game_status = False
    break


  else:

     
    player1_cards = []
    
    player2_cards = []
    
    player1_cards.append(player1.remove_one())
    player2_cards.append(player2.remove_one())
    
    

    print(player1)
    print('')
    print(player2)


    at_war = True

    while at_war == True:


      if player1_cards[-1].value > player2_cards[-1].value:

        player1.add_cards(player1_cards)
        player1.add_cards(player2_cards)
        at_war = False
        break


      elif player2_cards[-1].value > player1_cards[-1].value:

        player2.add_cards(player1_cards)
        player2.add_cards(player2_cards)
        at_war = False
        break

      else:     

        print('WAR!!')
        if len(player1.all_cards) < 5:
            
          print('Player 2 won')

          game_status = False
          at_war = False
          
          break

        elif len(player2.all_cards) <5:

          print('Player 1 won')
          game_status = False
          at_war = False
          break

        if len(player1.all_cards) >= 5 and len(player2.all_cards) >= 5:

          for i in range(5):
            player1_cards.append(player1.remove_one())
            player2_cards.append(player2.remove_one())

          continue            

     


if len(player1.all_cards) == 0:
  print('Player 2 won')

elif len(player2.all_cards) == 0:
  print('Player 1 won')

# %% [markdown]
# #FAILED ATTEMPTS

# %%
player1_name = input('Enter the name of Player1: ')

player2_name = input('Enter the name of Player2: ')

player1 = Player(player1_name)
player2 = Player(player2_name)
newdeck = Deck()
newdeck.shuffle()

#splitting the deck among the two players - alternate card from deck goes to each player respectively

for i in range(0,len(newdeck.all_cards)-1,2):  

  player1.add_cards(newdeck.all_cards[i])
  player2.add_cards(newdeck.all_cards[i+1])


print(player1)
print(player2)
# Out:
# Enter the name of Player1: rick
# Enter the name of Player2: morty
# Player rick has 26 cards.
# Player morty has 26 cards.

# %%
print(player1)
print(player2)

player1_card = player1.remove_one()
player2_card = player2.remove_one()
print('player1_card',player1_card.value)
print('player2_card',player2_card.value)

if player1_card.value > player2_card.value:

  player1.add_cards(player1_card)
  player1.add_cards(player2_card)

  print('p1>p2', player1)

elif player2_card.value > player1_card.value:

  player2.add_cards(player2_card)
  player2.add_cards(player1_card)

  print('p2>p1',player2)

else:
  player1_list = []
  player2_list = []
  for i in range(3):

    if player1.all_cards != [] and player2.all_cards != []:

      player1_list.append(player1.remove_one())
      player2_list.append(player2.remove_one())

    elif player1.all_cards == [] or player2.all_cards == []:

      break

  print('player1_list',player1_list)
  print('player2_list',player2_list)
        
  if player1_list[-1].value > player2_list[-1].value:

    player1.add_cards(player1_list)
    player1.add_cards(player2_list)
           
  elif player1_list[-1].value < player2_list[-1].value:

    player2.add_cards(player2_list)
    player2.add_cards(player1_list)
# Out:
# Player rick has 23 cards.
# Player morty has 27 cards.
# player1_card 5
# player2_card 7
# p2>p1 Player morty has 28 cards.

# %% [markdown]
# FAILED - GAMELOGIC

# %%
#create 2 new instances of the player class

player1_name = input('Enter the name of Player1: ')

player2_name = input('Enter the name of Player2: ')

player1 = Player(player1_name)
player2 = Player(player2_name)
newdeck = Deck()
newdeck.shuffle()

#splitting the deck among the two players - alternate card from deck goes to each player respectively

for i in range(0,len(newdeck.all_cards)-1,2):  

  player1.add_cards(newdeck.all_cards[i])
  player2.add_cards(newdeck.all_cards[i+1])

#for x in range(26):

 # player1.add_cards(newdeck.deal_one())
  #player2.add_cards(newdeck.deal_one())

print(player1)
print(player2)


game_status = True
    
round_num = 0
while game_status == True:

  round_num +=1
  print(f"Round {round_num}")


  if len(player1.all_cards) == 0:

    print('Player 1 out of cards'+ player2.name + 'Wins!')
    game_status = False
    break
  
  if len(player2.all_cards) == 0:

    print('Player 2 out of cards' + player1.name + 'Wins!')
    game_status = False
    break



  print(player1)
  print(player2)
     
  player_cards = []
  player1_card = player1.remove_one()
  player2_card = player2.remove_one()
  player_cards.append(player1_card)
  player_cards.append(player2_card)

  for i in player_cards:

    print(i.value)
    



  if player1_card.value > player2_card.value:

    print('player1 card is more')


    player1.add_cards(player_cards)
      #player1.add_cards(player2_cards)

      #print('p1>p2', player1)

  elif player2_card.value > player1_card.value:

      player2.add_cards(player_cards)
      #player2.add_cards(player1_cards)

      #print('p2>p1',player2)
      
  else:

    

    war_x = True
    inner_while = 0

    while war_x == True and game_status == True:  #we will make the players draw 3 cards if both cards are equal
      player1_list = []
      player2_list = []

      card_list = []

      inner_while+=1
      print('Inner while loop count',inner_while)       
        




      if len(player1.all_cards) < 5:
            
        print('Player 2 won')

        game_status = False
        war_x = False
          
        break

      elif len(player2.all_cards) <5:

        print('Player 1 won')
        game_status = False
        war_x = False
        break


      if len(player1.all_cards) >= 5 and len(player2.all_cards) >= 5:

        for i in range(5):

          player1_list.append(player1.remove_one())
          player2_list.append(player2.remove_one())



          
          
        
      else: 
        war_x = True     

     
print(player1)
print(player2)

if len(player1.all_cards) == 0:
  print('Player 2 won')

elif len(player2.all_cards) == 0:
  print('Player 1 won')
# Out:
# Enter the name of Player1: False
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     582         """
# --> 583         parts = [self.recv(flags, copy=copy, track=track)]
#     584         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-140c5a6af197> in <module>()
#       3 player1_name = input('Enter the name of Player1: ')
#       4
# ----> 5 player2_name = input('Enter the name of Player2: ')
#       6
#       7 player1 = Player(player1_name)
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %%
#create 2 new instances of the player class

player1_name = input('Enter the name of Player1: ')

player2_name = input('Enter the name of Player2: ')

player1 = Player(player1_name)
player2 = Player(player2_name)
newdeck = Deck()
newdeck.shuffle()

#splitting the deck among the two players - alternate card from deck goes to each player respectively

for i in range(0,len(newdeck.all_cards)-1,2):  

  player1.add_cards(newdeck.all_cards[i])
  player2.add_cards(newdeck.all_cards[i+1])


print(player1)
print(player2)


if len(player1.all_cards) != 0 or len(player2.all_cards) != 0:
    game_status = True
    

while game_status == True:


  if len(player1.all_cards) == 0 or len(player2.all_cards) == 0:
    game_status = False


  else:

      
    player1_card = player1.remove_one()
    player2_card = player2.remove_one()
    print('player1_card_value: ',player1_card.value)
    print('')
    print('player2_card_value: ',player2_card.value)
    print('')
    print(player1)
    print('')
    print(player2)


    if player1_card.value > player2_card.value:

      player1.add_cards(player1_card)
      player1.add_cards(player2_card)

      print('p1>p2', player1)

    elif player2_card.value > player1_card.value:

      player2.add_cards(player1_card)
      player2.add_cards(player2_card)

      print('p2>p1',player2)

    else:

      print('EQUAL')

      war_x = True
      inner_while = 0

      while war_x == True and game_status == True:  #we will make the players draw 3 cards if both cards are equal
        player1_list = []
        player2_list = []

        inner_while+=1
        print('Inner while loop count',inner_while)

        
        for i in range(3):

          if player1.all_cards != [] and player2.all_cards != []:

            player1_list.append(player1.remove_one())
            player2_list.append(player2.remove_one())

          elif player1.all_cards == [] or player2.all_cards == []:

            game_status = False

        print('player1_list',player1_list)
        print('player2_list',player2_list)
        
        if player1_list[-1].value > player2_list[-1].value:

          player1.add_cards(player1_list)
          player1.add_cards(player2_list)
          war_x = False

          

        elif player1_list[-1].value < player2_list[-1].value:

          player2.add_cards(player2_list)
          player2.add_cards(player1_list)
          war_x = False
        
        else: 
          war_x = True     



      
print(player1)
print(player2)

if len(player1.all_cards) == 0:
  print('Player 2 won')

elif len(player2.all_cards) == 0:
  print('Player 1 won')

# %%
PC = []
P1 = 12
P2 = 12
PC.append(P1)
PC.append(P2)

# %%
PC
# Out:
# [12, 12]

# %%
PK = []
PK.extend(PC)

# %%
PK
# Out:
# [12, 12]

# %%
player1_name = input('Enter the name of Player1: ')

player2_name = input('Enter the name of Player2: ')

player1 = Player(player1_name)
player2 = Player(player2_name)
newdeck = Deck()
# Out:
# Enter the name of Player1: rick
# Enter the name of Player2: morty

# %%
newdeck.shuffle()

# %%
#create 2 new instances of the player class



#splitting the deck among the two players - alternate card from deck goes to each player respectively

#for i in range(0,len(newdeck.all_cards)-1,2):  

 # player1.add_cards(newdeck.all_cards[i])
  #player2.add_cards(newdeck.all_cards[i+1])

for x in range(20):

  player1.add_cards(newdeck.deal_one())
  player2.add_cards(newdeck.deal_one())

print(player1)
print(player2)


game_status = True
    
round_num = 0
while game_status == True:

  round_num +=1
  print(f"Round {round_num}")


  if len(player1.all_cards) == 0:

    print('Player 1 out of cards'+ player2.name + 'Wins!')
    game_status = False
    break
  
  if len(player2.all_cards) == 0:

    print('Player 2 out of cards' + player1.name + 'Wins!')
    game_status = False
    break


  else:
    print(player1)
    print(player2)
     
    player_cards = []
    player1_card = player1.remove_one()
    player2_card = player2.remove_one()
    player_cards.append(player1_card)
    player_cards.append(player2_card)
    
    


    print('player1_card_value: ',player1_card.value)
    print('')
    print('player2_card_value: ',player2_card.value)   


    at_war = True

    

    if player1_card.value == player2_card.value:  

      print('at war')

      while at_war == True:


        player1_list = []
        player2_list = []   
        player_cards = []    


        if len(player1.all_cards) < 5:
            
          print('Player 1 doesnt hve enough cards 2 won')

          game_status = False
          at_war = False
          
          break

        elif len(player2.all_cards) <5:

          print('Player 2 doesnt hve enough cards 1 won')
          game_status = False
          at_war = False
          break

        if len(player1.all_cards) >= 5 and len(player2.all_cards) >= 5:

          for i in range(5):
            player1_list.append(player1.remove_one())
            player2_list.append(player2.remove_one())


          player_cards.extend(player1_list)
          player_cards.extend(player2_list)

          print("CARD LIST LEN", len(player_cards))

          if player1_list[0].value > player2_list[0].value:

            print('player1 card value',player1_list[0].value)
            print('player2 card value',player2_list[0].value)

            print('player 1 card has more value in war')


            player1.add_cards(player_cards)
            print(player1)
            at_war = False
            break

          


          elif player1_list[0].value < player2_list[0].value:

            print('player1 card value',player1_list[0].value)
            print('player2 card value',player2_list[0].value)


            print('player 2 card has more value')

            player2.add_cards(player_cards)
            print(player2)
          #player2.add_cards(player1_list)
            at_war = False
            break

      


    elif player1_card.value > player2_card.value:

      print('len of player_cards: ', len(player_cards))
      print(player_cards)
      player1.add_cards(player_cards)

      print('no of cards with player1 as he won',player1)
      print('no of cards with player2 as he lost',player2)
      #player1.add_cards(player2_cards)

      #print('p1>p2', player1)

    elif player2_card.value > player1_card.value:

      print('len of player_cards: ', len(player_cards))

      player2.add_cards(player_cards)
      print('no of cards with player2 as he won',player2)
      print('no of cards with player1 as he lost',player1)
     
#print(player1)
#print(player2)

#if len(player1.all_cards) == 0:
 # print('Player 2 won')

#elif len(player2.all_cards) == 0:
 # print('Player 1 won')
# Out:
# Streaming output truncated to the last 5000 lines.
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111850>, <__main__.Card object at 0x7febf5111610>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1599
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  4
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1600
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  8
#
# player2_card_value:  2
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111f50>, <__main__.Card object at 0x7febf5111a90>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1601
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  6
#
# player2_card_value:  11
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1602
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  12
#
# player2_card_value:  2
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111990>, <__main__.Card object at 0x7febf5111fd0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1603
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  7
#
# player2_card_value:  12
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1604
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  13
#
# player2_card_value:  5
# len of player_cards:  2
# [<__main__.Card object at 0x7febf51113d0>, <__main__.Card object at 0x7febf5111a50>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1605
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  7
#
# player2_card_value:  14
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1606
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  9
#
# player2_card_value:  5
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111b10>, <__main__.Card object at 0x7febf5111490>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1607
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  3
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1608
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  14
#
# player2_card_value:  6
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111850>, <__main__.Card object at 0x7febf5111cd0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1609
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  4
#
# player2_card_value:  14
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1610
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  8
#
# player2_card_value:  6
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111f50>, <__main__.Card object at 0x7febf5111690>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1611
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  2
#
# player2_card_value:  14
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1612
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  12
#
# player2_card_value:  4
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111990>, <__main__.Card object at 0x7febf51114d0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1613
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  2
#
# player2_card_value:  9
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1614
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  13
#
# player2_card_value:  3
# len of player_cards:  2
# [<__main__.Card object at 0x7febf51113d0>, <__main__.Card object at 0x7febf5111910>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1615
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  5
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1616
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  9
#
# player2_card_value:  5
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111b10>, <__main__.Card object at 0x7febf5114e50>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1617
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  5
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1618
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  14
#
# player2_card_value:  3
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111850>, <__main__.Card object at 0x7febf5111650>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1619
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  6
#
# player2_card_value:  12
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1620
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  8
#
# player2_card_value:  3
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111f50>, <__main__.Card object at 0x7febf5104bd0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1621
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  6
#
# player2_card_value:  8
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1622
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  12
#
# player2_card_value:  4
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111990>, <__main__.Card object at 0x7febfacb83d0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1623
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  4
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1624
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  13
#
# player2_card_value:  6
# len of player_cards:  2
# [<__main__.Card object at 0x7febf51113d0>, <__main__.Card object at 0x7febf5111950>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1625
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  3
#
# player2_card_value:  11
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1626
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  9
#
# player2_card_value:  7
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111b10>, <__main__.Card object at 0x7febf51116d0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1627
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  5
#
# player2_card_value:  12
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1628
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  14
#
# player2_card_value:  7
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111850>, <__main__.Card object at 0x7febf5111090>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1629
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  3
#
# player2_card_value:  14
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1630
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  8
#
# player2_card_value:  3
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111f50>, <__main__.Card object at 0x7febf5111c50>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1631
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  3
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1632
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  12
#
# player2_card_value:  4
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111990>, <__main__.Card object at 0x7febf5111610>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1633
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  4
#
# player2_card_value:  14
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1634
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  13
#
# player2_card_value:  2
# len of player_cards:  2
# [<__main__.Card object at 0x7febf51113d0>, <__main__.Card object at 0x7febf5111a90>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1635
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  6
#
# player2_card_value:  14
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1636
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  9
#
# player2_card_value:  2
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111b10>, <__main__.Card object at 0x7febf5111fd0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1637
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  7
#
# player2_card_value:  9
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1638
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  14
#
# player2_card_value:  5
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111850>, <__main__.Card object at 0x7febf5111a50>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1639
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  7
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1640
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  8
#
# player2_card_value:  5
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111f50>, <__main__.Card object at 0x7febf5111490>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1641
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  3
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1642
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  12
#
# player2_card_value:  6
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111990>, <__main__.Card object at 0x7febf5111cd0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1643
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  4
#
# player2_card_value:  12
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1644
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  13
#
# player2_card_value:  6
# len of player_cards:  2
# [<__main__.Card object at 0x7febf51113d0>, <__main__.Card object at 0x7febf5111690>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1645
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  2
#
# player2_card_value:  8
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1646
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  9
#
# player2_card_value:  4
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111b10>, <__main__.Card object at 0x7febf51114d0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1647
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  2
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1648
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  14
#
# player2_card_value:  3
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111850>, <__main__.Card object at 0x7febf5111910>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1649
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  5
#
# player2_card_value:  11
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1650
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  8
#
# player2_card_value:  5
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111f50>, <__main__.Card object at 0x7febf5114e50>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1651
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  5
#
# player2_card_value:  12
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1652
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  12
#
# player2_card_value:  3
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111990>, <__main__.Card object at 0x7febf5111650>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1653
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  6
#
# player2_card_value:  14
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1654
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  13
#
# player2_card_value:  3
# len of player_cards:  2
# [<__main__.Card object at 0x7febf51113d0>, <__main__.Card object at 0x7febf5104bd0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1655
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  6
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1656
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  9
#
# player2_card_value:  4
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111b10>, <__main__.Card object at 0x7febfacb83d0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1657
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  4
#
# player2_card_value:  14
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1658
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  14
#
# player2_card_value:  6
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111850>, <__main__.Card object at 0x7febf5111950>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1659
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  3
#
# player2_card_value:  14
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1660
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  8
#
# player2_card_value:  7
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111f50>, <__main__.Card object at 0x7febf51116d0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1661
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  5
#
# player2_card_value:  9
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1662
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  12
#
# player2_card_value:  7
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111990>, <__main__.Card object at 0x7febf5111090>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1663
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  3
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1664
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  13
#
# player2_card_value:  3
# len of player_cards:  2
# [<__main__.Card object at 0x7febf51113d0>, <__main__.Card object at 0x7febf5111c50>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1665
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  3
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1666
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  9
#
# player2_card_value:  4
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111b10>, <__main__.Card object at 0x7febf5111610>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1667
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  4
#
# player2_card_value:  12
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1668
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  14
#
# player2_card_value:  2
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111850>, <__main__.Card object at 0x7febf5111a90>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1669
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  6
#
# player2_card_value:  8
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1670
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  8
#
# player2_card_value:  2
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111f50>, <__main__.Card object at 0x7febf5111fd0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1671
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  7
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1672
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  12
#
# player2_card_value:  5
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111990>, <__main__.Card object at 0x7febf5111a50>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1673
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  7
#
# player2_card_value:  11
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1674
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  13
#
# player2_card_value:  5
# len of player_cards:  2
# [<__main__.Card object at 0x7febf51113d0>, <__main__.Card object at 0x7febf5111490>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1675
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  3
#
# player2_card_value:  12
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1676
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  9
#
# player2_card_value:  6
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111b10>, <__main__.Card object at 0x7febf5111cd0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1677
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  4
#
# player2_card_value:  14
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1678
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  14
#
# player2_card_value:  6
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111850>, <__main__.Card object at 0x7febf5111690>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1679
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  2
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1680
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  8
#
# player2_card_value:  4
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111f50>, <__main__.Card object at 0x7febf51114d0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1681
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  2
#
# player2_card_value:  14
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1682
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  12
#
# player2_card_value:  3
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111990>, <__main__.Card object at 0x7febf5111910>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1683
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  5
#
# player2_card_value:  14
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1684
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  13
#
# player2_card_value:  5
# len of player_cards:  2
# [<__main__.Card object at 0x7febf51113d0>, <__main__.Card object at 0x7febf5114e50>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1685
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  5
#
# player2_card_value:  9
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1686
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  9
#
# player2_card_value:  3
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111b10>, <__main__.Card object at 0x7febf5111650>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1687
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  6
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1688
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  14
#
# player2_card_value:  3
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111850>, <__main__.Card object at 0x7febf5104bd0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1689
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  6
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1690
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  8
#
# player2_card_value:  4
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111f50>, <__main__.Card object at 0x7febfacb83d0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1691
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  4
#
# player2_card_value:  12
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1692
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  12
#
# player2_card_value:  6
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111990>, <__main__.Card object at 0x7febf5111950>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1693
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  3
#
# player2_card_value:  8
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1694
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  13
#
# player2_card_value:  7
# len of player_cards:  2
# [<__main__.Card object at 0x7febf51113d0>, <__main__.Card object at 0x7febf51116d0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1695
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  5
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1696
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  9
#
# player2_card_value:  7
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111b10>, <__main__.Card object at 0x7febf5111090>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1697
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  3
#
# player2_card_value:  11
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1698
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  14
#
# player2_card_value:  3
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111850>, <__main__.Card object at 0x7febf5111c50>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1699
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  3
#
# player2_card_value:  12
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1700
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  8
#
# player2_card_value:  4
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111f50>, <__main__.Card object at 0x7febf5111610>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1701
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  4
#
# player2_card_value:  14
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1702
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  12
#
# player2_card_value:  2
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111990>, <__main__.Card object at 0x7febf5111a90>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1703
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  6
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1704
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  13
#
# player2_card_value:  2
# len of player_cards:  2
# [<__main__.Card object at 0x7febf51113d0>, <__main__.Card object at 0x7febf5111fd0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1705
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  7
#
# player2_card_value:  14
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1706
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  9
#
# player2_card_value:  5
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111b10>, <__main__.Card object at 0x7febf5111a50>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1707
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  7
#
# player2_card_value:  14
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1708
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  14
#
# player2_card_value:  5
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111850>, <__main__.Card object at 0x7febf5111490>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1709
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  3
#
# player2_card_value:  9
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1710
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  8
#
# player2_card_value:  6
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111f50>, <__main__.Card object at 0x7febf5111cd0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1711
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  4
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1712
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  12
#
# player2_card_value:  6
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111990>, <__main__.Card object at 0x7febf5111690>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1713
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  2
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1714
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  13
#
# player2_card_value:  4
# len of player_cards:  2
# [<__main__.Card object at 0x7febf51113d0>, <__main__.Card object at 0x7febf51114d0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1715
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  2
#
# player2_card_value:  12
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1716
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  9
#
# player2_card_value:  3
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111b10>, <__main__.Card object at 0x7febf5111910>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1717
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  5
#
# player2_card_value:  8
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1718
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  14
#
# player2_card_value:  5
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111850>, <__main__.Card object at 0x7febf5114e50>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1719
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  5
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1720
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  8
#
# player2_card_value:  3
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111f50>, <__main__.Card object at 0x7febf5111650>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1721
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  6
#
# player2_card_value:  11
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1722
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  12
#
# player2_card_value:  3
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111990>, <__main__.Card object at 0x7febf5104bd0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1723
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  6
#
# player2_card_value:  12
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1724
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  13
#
# player2_card_value:  4
# len of player_cards:  2
# [<__main__.Card object at 0x7febf51113d0>, <__main__.Card object at 0x7febfacb83d0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1725
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  4
#
# player2_card_value:  14
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1726
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  9
#
# player2_card_value:  6
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111b10>, <__main__.Card object at 0x7febf5111950>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1727
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  3
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1728
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  14
#
# player2_card_value:  7
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111850>, <__main__.Card object at 0x7febf51116d0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1729
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  5
#
# player2_card_value:  14
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1730
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  8
#
# player2_card_value:  7
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111f50>, <__main__.Card object at 0x7febf5111090>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1731
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  3
#
# player2_card_value:  14
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1732
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  12
#
# player2_card_value:  3
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111990>, <__main__.Card object at 0x7febf5111c50>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1733
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  3
#
# player2_card_value:  9
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1734
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  13
#
# player2_card_value:  4
# len of player_cards:  2
# [<__main__.Card object at 0x7febf51113d0>, <__main__.Card object at 0x7febf5111610>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1735
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  4
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1736
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  9
#
# player2_card_value:  2
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111b10>, <__main__.Card object at 0x7febf5111a90>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1737
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  6
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1738
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  14
#
# player2_card_value:  2
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111850>, <__main__.Card object at 0x7febf5111fd0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1739
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  7
#
# player2_card_value:  12
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1740
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  8
#
# player2_card_value:  5
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111f50>, <__main__.Card object at 0x7febf5111a50>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1741
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  7
#
# player2_card_value:  8
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1742
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  12
#
# player2_card_value:  5
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111990>, <__main__.Card object at 0x7febf5111490>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1743
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  3
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1744
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  13
#
# player2_card_value:  6
# len of player_cards:  2
# [<__main__.Card object at 0x7febf51113d0>, <__main__.Card object at 0x7febf5111cd0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1745
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  4
#
# player2_card_value:  11
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1746
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  9
#
# player2_card_value:  6
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111b10>, <__main__.Card object at 0x7febf5111690>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1747
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  2
#
# player2_card_value:  12
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1748
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  14
#
# player2_card_value:  4
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111850>, <__main__.Card object at 0x7febf51114d0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1749
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  2
#
# player2_card_value:  14
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1750
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  8
#
# player2_card_value:  3
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111f50>, <__main__.Card object at 0x7febf5111910>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1751
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  5
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1752
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  12
#
# player2_card_value:  5
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111990>, <__main__.Card object at 0x7febf5114e50>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1753
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  5
#
# player2_card_value:  14
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1754
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  13
#
# player2_card_value:  3
# len of player_cards:  2
# [<__main__.Card object at 0x7febf51113d0>, <__main__.Card object at 0x7febf5111650>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 1755
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  6
#
# player2_card_value:  14
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 1756
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  9
#
# player2_card_value:  3
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111b10>, <__main__.Card object at 0x7febf5104bd0>]
# no of cards with player1 as he won Player rick has 11 cards.
# ...
# Player morty has 24 cards.
# player1_card_value:  14
#
# player2_card_value:  2
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111850>, <__main__.Card object at 0x7febf5111fd0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 2079
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  7
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 2080
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  8
#
# player2_card_value:  5
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111f50>, <__main__.Card object at 0x7febf5111a50>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 2081
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  7
#
# player2_card_value:  11
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 2082
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  12
#
# player2_card_value:  5
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111990>, <__main__.Card object at 0x7febf5111490>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 2083
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  3
#
# player2_card_value:  12
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 2084
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  13
#
# player2_card_value:  6
# len of player_cards:  2
# [<__main__.Card object at 0x7febf51113d0>, <__main__.Card object at 0x7febf5111cd0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 2085
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  4
#
# player2_card_value:  14
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 2086
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  9
#
# player2_card_value:  6
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111b10>, <__main__.Card object at 0x7febf5111690>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 2087
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  2
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 2088
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  14
#
# player2_card_value:  4
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111850>, <__main__.Card object at 0x7febf51114d0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 2089
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  2
#
# player2_card_value:  14
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 2090
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  8
#
# player2_card_value:  3
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111f50>, <__main__.Card object at 0x7febf5111910>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 2091
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  5
#
# player2_card_value:  14
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 2092
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  12
#
# player2_card_value:  5
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111990>, <__main__.Card object at 0x7febf5114e50>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 2093
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  5
#
# player2_card_value:  9
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 2094
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  13
#
# player2_card_value:  3
# len of player_cards:  2
# [<__main__.Card object at 0x7febf51113d0>, <__main__.Card object at 0x7febf5111650>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 2095
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  6
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 2096
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  9
#
# player2_card_value:  3
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111b10>, <__main__.Card object at 0x7febf5104bd0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 2097
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  6
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 2098
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  14
#
# player2_card_value:  4
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111850>, <__main__.Card object at 0x7febfacb83d0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 2099
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  4
#
# player2_card_value:  12
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 2100
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  8
#
# player2_card_value:  6
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111f50>, <__main__.Card object at 0x7febf5111950>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 2101
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  3
#
# player2_card_value:  8
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 2102
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  12
#
# player2_card_value:  7
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111990>, <__main__.Card object at 0x7febf51116d0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 2103
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  5
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 2104
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  13
#
# player2_card_value:  7
# len of player_cards:  2
# [<__main__.Card object at 0x7febf51113d0>, <__main__.Card object at 0x7febf5111090>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 2105
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  3
#
# player2_card_value:  11
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 2106
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  9
#
# player2_card_value:  3
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111b10>, <__main__.Card object at 0x7febf5111c50>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 2107
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  3
#
# player2_card_value:  12
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 2108
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  14
#
# player2_card_value:  4
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111850>, <__main__.Card object at 0x7febf5111610>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 2109
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  4
#
# player2_card_value:  14
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 2110
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  8
#
# player2_card_value:  2
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111f50>, <__main__.Card object at 0x7febf5111a90>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 2111
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  6
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 2112
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  12
#
# player2_card_value:  2
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111990>, <__main__.Card object at 0x7febf5111fd0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 2113
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  7
#
# player2_card_value:  14
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 2114
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  13
#
# player2_card_value:  5
# len of player_cards:  2
# [<__main__.Card object at 0x7febf51113d0>, <__main__.Card object at 0x7febf5111a50>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 2115
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  7
#
# player2_card_value:  14
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 2116
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  9
#
# player2_card_value:  5
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111b10>, <__main__.Card object at 0x7febf5111490>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 2117
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  3
#
# player2_card_value:  9
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 2118
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  14
#
# player2_card_value:  6
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111850>, <__main__.Card object at 0x7febf5111cd0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 2119
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  4
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 2120
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  8
#
# player2_card_value:  6
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111f50>, <__main__.Card object at 0x7febf5111690>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 2121
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  2
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 2122
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  12
#
# player2_card_value:  4
# len of player_cards:  2
# [<__main__.Card object at 0x7febf5111990>, <__main__.Card object at 0x7febf51114d0>]
# no of cards with player1 as he won Player rick has 11 cards.
# no of cards with player2 as he lost Player morty has 23 cards.
# Round 2123
# Player rick has 11 cards.
# Player morty has 23 cards.
# player1_card_value:  2
#
# player2_card_value:  12
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
# no of cards with player1 as he lost Player rick has 10 cards.
# Round 2124
# Player rick has 10 cards.
# Player morty has 24 cards.
# player1_card_value:  13
#
# player2_card_value:  3
# len of player_cards:  2
# [<__main__.Card object at 0x7febf51113d0>, <__main__.Card object at 0x7febf5111910>]
# no of cards with player1 as he won
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-d563dace211d> in <module>()
#     142       player1.add_cards(player_cards)
#     143
# --> 144       print('no of cards with player1 as he won',player1)
#     145       print('no of cards with player2 as he lost',player2)
#     146       #player1.add_cards(player2_cards)
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in write(self, string)
#     398             is_child = (not self._is_master_process())
#     399             # only touch the buffer in the IO thread to avoid races
# --> 400             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     401             if is_child:
#     402                 # newlines imply flush in subprocesses
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     503                 )
#     504             data.group = group
# --> 505         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     506
#     507     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
OK

          if player1_list[0].value > player2_list[0].value:

            player1.add_cards(card_list)
            at_war = False
            break


          elif player1_list[0].value < player2_list[0].value:

            player2.add_cards(card_list)
          #player2.add_cards(player1_list)
            at_war = False
            break

          else:

            at_war = True

# %%
a = [1,2,3]
a.append(4)
a
# Out:
# [1, 2, 3, 4]

# %%
print(a[-1])
# Out:
# 4
