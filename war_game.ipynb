# %% [markdown]
# <a href="https://colab.research.google.com/github/dikshap07/OOPs-with-Python/blob/master/war_game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
 
suits = ['Hearts','Clubs','Spades','Diamonds']
 
ranks = ['Two','Three','Four','Five','Six','Seven','Eight','Nine','Ten','Jack','Queen','King','Ace']
 
values = {'Two': 2, 'Three': 3, 'Four': 4, 'Five': 5, 'Six' : 6 , 'Seven' :7, 'Eight': 8,'Nine':9,
          'Ten':10,'Jack':11, 'Queen': 12,'King': 13,'Ace':14 }


class Card():  
    
    
    def __init__(self,suit,rank):
        
        self.suit = suit
        self.rank = rank
        self.value = values[rank]
    
    #string method
    def __str__(self):
        
        return self.rank + ' of ' + self.suit 


class Deck():

  def __init__(self):

    self.all_cards = []  #list of objects

    for suit in suits:

      for rank in ranks:
        #create card object

        created_card = Card(suit,rank)

        self.all_cards.append(created_card)


  def shuffle(self):   #method to shuffle the card

    random.shuffle(self.all_cards)



  def deal_one(self):

    return self.all_cards.pop()  #we want the last card from deck




#player class

#used to hold a player's current list of cards
#player should be able to add or remove cards from their hands
#player shoyld be able to add single or mulitple cards to their list of card objects
class Player():

  def __init__(self,name):

    self.name  = name
    self.all_cards = []

  def remove_one(self):

    return self.all_cards.pop(0)    #to remove card from beginning of the list

    

  def add_cards(self,new_cards):


    if type(new_cards) == type([]):

      self.all_cards.extend(new_cards)

    else:

      self.all_cards.append(new_cards)

  def __str__(self):
    return f'Player {self.name} has {len(self.all_cards)} cards.'

# %% [markdown]
# #GAME LOGIC

# %%
#create 2 new instances of the player class

player1_name = input('Enter the name of Player1: ')

player2_name = input('Enter the name of Player2: ')

player1 = Player(player1_name)
player2 = Player(player2_name)
newdeck = Deck()
newdeck.shuffle()

#splitting the deck among the two players - alternate card from deck goes to each player respectively

for i in range(0,len(newdeck.all_cards)-1,2):  

  player1.add_cards(newdeck.all_cards[i])
  player2.add_cards(newdeck.all_cards[i+1])



print(player1)
print(player2)


game_status = True
    
round_num = 0
while game_status == True:

  round_num +=1
  print(f"Round {round_num}")


  if len(player1.all_cards) == 0:

    print('Player 1 out of cards'+ player2.name + 'Wins!')
    game_status = False
    break
  
  if len(player2.all_cards) == 0:

    print('Player 2 out of cards' + player1.name + 'Wins!')
    game_status = False
    break


  else:

     
    player1_cards = []
    
    player2_cards = []
    
    player1_cards.append(player1.remove_one())
    player2_cards.append(player2.remove_one())
    
    

    print(player1)
    print('')
    print(player2)


    at_war = True

    while at_war == True:


      if player1_cards[-1].value > player2_cards[-1].value:

        player1.add_cards(player1_cards)
        player1.add_cards(player2_cards)
        at_war = False
        break


      elif player2_cards[-1].value > player1_cards[-1].value:

        player2.add_cards(player1_cards)
        player2.add_cards(player2_cards)
        at_war = False
        break

      else:     

        print('WAR!!')
        if len(player1.all_cards) < 5:
            
          print('Player 2 won')

          game_status = False
          at_war = False
          
          break

        elif len(player2.all_cards) <5:

          print('Player 1 won')
          game_status = False
          at_war = False
          break

        if len(player1.all_cards) >= 5 and len(player2.all_cards) >= 5:

          for i in range(5):
            player1_cards.append(player1.remove_one())
            player2_cards.append(player2.remove_one())

          continue            

     


if len(player1.all_cards) == 0:
  print('Player 2 won')

elif len(player2.all_cards) == 0:
  print('Player 1 won')
# Out:
# Enter the name of Player1: r
# Enter the name of Player2: o
# Player r has 26 cards.
# Player o has 26 cards.
# Round 1
# Player r has 25 cards.
#
# Player o has 25 cards.
# Round 2
# Player r has 26 cards.
#
# Player o has 24 cards.
# Round 3
# Player r has 25 cards.
#
# Player o has 25 cards.
# Round 4
# Player r has 26 cards.
#
# Player o has 24 cards.
# Round 5
# Player r has 27 cards.
#
# Player o has 23 cards.
# Round 6
# Player r has 28 cards.
#
# Player o has 22 cards.
# Round 7
# Player r has 29 cards.
#
# Player o has 21 cards.
# Round 8
# Player r has 28 cards.
#
# Player o has 22 cards.
# Round 9
# Player r has 27 cards.
#
# Player o has 23 cards.
# Round 10
# Player r has 26 cards.
#
# Player o has 24 cards.
# Round 11
# Player r has 25 cards.
#
# Player o has 25 cards.
# Round 12
# Player r has 26 cards.
#
# Player o has 24 cards.
# WAR!!
# Round 13
# Player r has 32 cards.
#
# Player o has 18 cards.
# Round 14
# Player r has 31 cards.
#
# Player o has 19 cards.
# Round 15
# Player r has 30 cards.
#
# Player o has 20 cards.
# Round 16
# Player r has 31 cards.
#
# Player o has 19 cards.
# Round 17
# Player r has 32 cards.
#
# Player o has 18 cards.
# Round 18
# Player r has 31 cards.
#
# Player o has 19 cards.
# Round 19
# Player r has 30 cards.
#
# Player o has 20 cards.
# Round 20
# Player r has 31 cards.
#
# Player o has 19 cards.
# Round 21
# Player r has 30 cards.
#
# Player o has 20 cards.
# WAR!!
# Round 22
# Player r has 36 cards.
#
# Player o has 14 cards.
# Round 23
# Player r has 35 cards.
#
# Player o has 15 cards.
# Round 24
# Player r has 36 cards.
#
# Player o has 14 cards.
# Round 25
# Player r has 35 cards.
#
# Player o has 15 cards.
# Round 26
# Player r has 34 cards.
#
# Player o has 16 cards.
# Round 27
# Player r has 33 cards.
#
# Player o has 17 cards.
# Round 28
# Player r has 34 cards.
#
# Player o has 16 cards.
# Round 29
# Player r has 35 cards.
#
# Player o has 15 cards.
# Round 30
# Player r has 36 cards.
#
# Player o has 14 cards.
# Round 31
# Player r has 37 cards.
#
# Player o has 13 cards.
# Round 32
# Player r has 36 cards.
#
# Player o has 14 cards.
# Round 33
# Player r has 37 cards.
#
# Player o has 13 cards.
# Round 34
# Player r has 36 cards.
#
# Player o has 14 cards.
# Round 35
# Player r has 35 cards.
#
# Player o has 15 cards.
# Round 36
# Player r has 36 cards.
#
# Player o has 14 cards.
# Round 37
# Player r has 35 cards.
#
# Player o has 15 cards.
# Round 38
# Player r has 36 cards.
#
# Player o has 14 cards.
# WAR!!
# Round 39
# Player r has 42 cards.
#
# Player o has 8 cards.
# Round 40
# Player r has 43 cards.
#
# Player o has 7 cards.
# Round 41
# Player r has 44 cards.
#
# Player o has 6 cards.
# Round 42
# Player r has 43 cards.
#
# Player o has 7 cards.
# Round 43
# Player r has 44 cards.
#
# Player o has 6 cards.
# Round 44
# Player r has 45 cards.
#
# Player o has 5 cards.
# Round 45
# Player r has 46 cards.
#
# Player o has 4 cards.
# Round 46
# Player r has 45 cards.
#
# Player o has 5 cards.
# Round 47
# Player r has 46 cards.
#
# Player o has 4 cards.
# Round 48
# Player r has 47 cards.
#
# Player o has 3 cards.
# Round 49
# Player r has 46 cards.
#
# Player o has 4 cards.
# Round 50
# Player r has 45 cards.
#
# Player o has 5 cards.
# Round 51
# Player r has 44 cards.
#
# Player o has 6 cards.
# Round 52
# Player r has 43 cards.
#
# Player o has 7 cards.
# Round 53
# Player r has 44 cards.
#
# Player o has 6 cards.
# Round 54
# Player r has 43 cards.
#
# Player o has 7 cards.
# Round 55
# Player r has 44 cards.
#
# Player o has 6 cards.
# Round 56
# Player r has 43 cards.
#
# Player o has 7 cards.
# Round 57
# Player r has 44 cards.
#
# Player o has 6 cards.
# Round 58
# Player r has 43 cards.
#
# Player o has 7 cards.
# Round 59
# Player r has 44 cards.
#
# Player o has 6 cards.
# Round 60
# Player r has 43 cards.
#
# Player o has 7 cards.
# Round 61
# Player r has 44 cards.
#
# Player o has 6 cards.
# Round 62
# Player r has 43 cards.
#
# Player o has 7 cards.
# Round 63
# Player r has 44 cards.
#
# Player o has 6 cards.
# Round 64
# Player r has 43 cards.
#
# Player o has 7 cards.
# Round 65
# Player r has 44 cards.
#
# Player o has 6 cards.
# WAR!!
# Round 66
# Player r has 50 cards.
#
# Player o has 0 cards.
# Round 67
# Player r has 49 cards.
#
# Player o has 1 cards.
# Round 68
# Player r has 48 cards.
#
# Player o has 2 cards.
# WAR!!
# Player 1 won

# %% [markdown]
# #GAMELOGIC - MY METHOD

# %%
#create 2 new instances of the player class
player1_name = input('Enter the name of Player1: ')

player2_name = input('Enter the name of Player2: ')

player1 = Player(player1_name)
player2 = Player(player2_name)
newdeck = Deck()
newdeck.shuffle()


#splitting the deck among the two players - alternate card from deck goes to each player respectively

for i in range(0,len(newdeck.all_cards)-1,2):
  player1.add_cards(newdeck.all_cards[i])
  player2.add_cards(newdeck.all_cards[i+1])


print(player1)
print(player2)


game_status = True
    
round_num = 0
while game_status == True:

  round_num +=1

  if round_num > 1000:
    random.shuffle(player1.all_cards)
    random.shuffle(player2.all_cards)
  print('')
  print(f"Round {round_num}")


  if len(player1.all_cards) == 0:

    print('Player 1 out of cards Player 1: '+ player2.name + ' Wins!')
    game_status = False
    break
  
  if len(player2.all_cards) == 0:

    print('Player 2 out of cards Player 2: ' + player1.name + ' Wins!')
    game_status = False
    break


  else:
    print('')
    print(player1)
    print('')
    print(player2)
     
    player_cards = []
    player1_card = player1.remove_one()
    player2_card = player2.remove_one()
    player_cards.append(player1_card)
    player_cards.append(player2_card)   


    print('player1_card_value: ',player1_card.value)
    print('')
    print('player2_card_value: ',player2_card.value)   


    at_war = True

    

    if player1_card.value == player2_card.value:  
      print('')
      print('!!!!    AT WARRR    !!!!')

      while at_war == True:
        player1_list = []
        player2_list = []   
        #player_cards = []    

        if len(player1.all_cards) < 5:
            
          print('Player 1 out of cards Player 2 '+ player2.name + ' Wins!')

          game_status = False
          at_war = False
          
          break

        elif len(player2.all_cards) <5:

          print('Player 2 out of cards Player 1 ' + player1.name + ' Wins!')
          game_status = False
          at_war = False
          break

        if len(player1.all_cards) >= 5 and len(player2.all_cards) >= 5:

          for i in range(5):
            player1_list.append(player1.remove_one())
            player2_list.append(player2.remove_one())


          player_cards.extend(player1_list)
          player_cards.extend(player2_list)
          print('')
          #print("CARD LIST LEN", len(player_cards))

          if player1_list[-1].value > player2_list[-1].value:

            #print('player1 card value',player1_list[-1].value)
            #print('player2 card value',player2_list[-1].value)
            #print('player 1 card has more value in war')
            player1.add_cards(player_cards)
            print('')
            print(player1)
            at_war = False
            break          


          elif player1_list[-1].value < player2_list[-1].value:

            #print('player1 card value',player1_list[-1].value)
            #print('player2 card value',player2_list[-1].value)
            #print('player 2 card has more value')
            player2.add_cards(player_cards)
            print('')
            print(player2)
           #player2.add_cards(player1_list)
            at_war = False
            break    


    elif player1_card.value > player2_card.value:

      #print('len of player_cards: ', len(player_cards))
      #print(player_cards)
      player1.add_cards(player_cards)
      #print('no of cards with player1 as he won',player1)
      print('')
      #print('no of cards with player2 as he lost',player2)
      #player1.add_cards(player2_cards)

      #print('p1>p2', player1)

    elif player2_card.value > player1_card.value:

      #print('len of player_cards: ', len(player_cards))
      player2.add_cards(player_cards)
      #print('no of cards with player2 as he won',player2)
      print('')
      #print('no of cards with player1 as he lost',player1)
# Out:
# Enter the name of Player1: rick
# Enter the name of Player2: morty
# Player rick has 26 cards.
# Player morty has 26 cards.
#
# Round 1
#
# Player rick has 26 cards.
#
# Player morty has 26 cards.
# player1_card_value:  4
#
# player2_card_value:  5
#
#
# Round 2
#
# Player rick has 25 cards.
#
# Player morty has 27 cards.
# player1_card_value:  6
#
# player2_card_value:  7
#
#
# Round 3
#
# Player rick has 24 cards.
#
# Player morty has 28 cards.
# player1_card_value:  8
#
# player2_card_value:  13
#
#
# Round 4
#
# Player rick has 23 cards.
#
# Player morty has 29 cards.
# player1_card_value:  12
#
# player2_card_value:  6
#
#
# Round 5
#
# Player rick has 24 cards.
#
# Player morty has 28 cards.
# player1_card_value:  9
#
# player2_card_value:  5
#
#
# Round 6
#
# Player rick has 25 cards.
#
# Player morty has 27 cards.
# player1_card_value:  7
#
# player2_card_value:  6
#
#
# Round 7
#
# Player rick has 26 cards.
#
# Player morty has 26 cards.
# player1_card_value:  14
#
# player2_card_value:  5
#
#
# Round 8
#
# Player rick has 27 cards.
#
# Player morty has 25 cards.
# player1_card_value:  10
#
# player2_card_value:  12
#
#
# Round 9
#
# Player rick has 26 cards.
#
# Player morty has 26 cards.
# player1_card_value:  2
#
# player2_card_value:  3
#
#
# Round 10
#
# Player rick has 25 cards.
#
# Player morty has 27 cards.
# player1_card_value:  2
#
# player2_card_value:  7
#
#
# Round 11
#
# Player rick has 24 cards.
#
# Player morty has 28 cards.
# player1_card_value:  4
#
# player2_card_value:  9
#
#
# Round 12
#
# Player rick has 23 cards.
#
# Player morty has 29 cards.
# player1_card_value:  9
#
# player2_card_value:  11
#
#
# Round 13
#
# Player rick has 22 cards.
#
# Player morty has 30 cards.
# player1_card_value:  14
#
# player2_card_value:  4
#
#
# Round 14
#
# Player rick has 23 cards.
#
# Player morty has 29 cards.
# player1_card_value:  12
#
# player2_card_value:  12
#
# !!!!    AT WARRR    !!!!
#
#
# Player rick has 29 cards.
#
# Round 15
#
# Player rick has 29 cards.
#
# Player morty has 23 cards.
# player1_card_value:  13
#
# player2_card_value:  14
#
#
# Round 16
#
# Player rick has 28 cards.
#
# Player morty has 24 cards.
# player1_card_value:  3
#
# player2_card_value:  10
#
#
# Round 17
#
# Player rick has 27 cards.
#
# Player morty has 25 cards.
# player1_card_value:  8
#
# player2_card_value:  5
#
#
# Round 18
#
# Player rick has 28 cards.
#
# Player morty has 24 cards.
# player1_card_value:  2
#
# player2_card_value:  11
#
#
# Round 19
#
# Player rick has 27 cards.
#
# Player morty has 25 cards.
# player1_card_value:  8
#
# player2_card_value:  11
#
#
# Round 20
#
# Player rick has 26 cards.
#
# Player morty has 26 cards.
# player1_card_value:  14
#
# player2_card_value:  13
#
#
# Round 21
#
# Player rick has 27 cards.
#
# Player morty has 25 cards.
# player1_card_value:  3
#
# player2_card_value:  13
#
#
# Round 22
#
# Player rick has 26 cards.
#
# Player morty has 26 cards.
# player1_card_value:  12
#
# player2_card_value:  4
#
#
# Round 23
#
# Player rick has 27 cards.
#
# Player morty has 25 cards.
# player1_card_value:  6
#
# player2_card_value:  5
#
#
# Round 24
#
# Player rick has 28 cards.
#
# Player morty has 24 cards.
# player1_card_value:  9
#
# player2_card_value:  6
#
#
# Round 25
#
# Player rick has 29 cards.
#
# Player morty has 23 cards.
# player1_card_value:  5
#
# player2_card_value:  7
#
#
# Round 26
#
# Player rick has 28 cards.
#
# Player morty has 24 cards.
# player1_card_value:  7
#
# player2_card_value:  8
#
#
# Round 27
#
# Player rick has 27 cards.
#
# Player morty has 25 cards.
# player1_card_value:  6
#
# player2_card_value:  13
#
#
# Round 28
#
# Player rick has 26 cards.
#
# Player morty has 26 cards.
# player1_card_value:  14
#
# player2_card_value:  10
#
#
# Round 29
#
# Player rick has 27 cards.
#
# Player morty has 25 cards.
# player1_card_value:  5
#
# player2_card_value:  12
#
#
# Round 30
#
# Player rick has 26 cards.
#
# Player morty has 26 cards.
# player1_card_value:  14
#
# player2_card_value:  2
#
#
# Round 31
#
# Player rick has 27 cards.
#
# Player morty has 25 cards.
# player1_card_value:  4
#
# player2_card_value:  3
#
#
# Round 32
#
# Player rick has 28 cards.
#
# Player morty has 24 cards.
# player1_card_value:  12
#
# player2_card_value:  2
#
#
# Round 33
#
# Player rick has 29 cards.
#
# Player morty has 23 cards.
# player1_card_value:  12
#
# player2_card_value:  7
#
#
# Round 34
#
# Player rick has 30 cards.
#
# Player morty has 22 cards.
# player1_card_value:  7
#
# player2_card_value:  4
#
#
# Round 35
#
# Player rick has 31 cards.
#
# Player morty has 21 cards.
# player1_card_value:  10
#
# player2_card_value:  9
#
#
# Round 36
#
# Player rick has 32 cards.
#
# Player morty has 20 cards.
# player1_card_value:  4
#
# player2_card_value:  9
#
#
# Round 37
#
# Player rick has 31 cards.
#
# Player morty has 21 cards.
# player1_card_value:  9
#
# player2_card_value:  11
#
#
# Round 38
#
# Player rick has 30 cards.
#
# Player morty has 22 cards.
# player1_card_value:  11
#
# player2_card_value:  13
#
#
# Round 39
#
# Player rick has 29 cards.
#
# Player morty has 23 cards.
# player1_card_value:  10
#
# player2_card_value:  14
#
#
# Round 40
#
# Player rick has 28 cards.
#
# Player morty has 24 cards.
# player1_card_value:  2
#
# player2_card_value:  3
#
#
# Round 41
#
# Player rick has 27 cards.
#
# Player morty has 25 cards.
# player1_card_value:  8
#
# player2_card_value:  10
#
#
# Round 42
#
# Player rick has 26 cards.
#
# Player morty has 26 cards.
# player1_card_value:  6
#
# player2_card_value:  2
#
#
# Round 43
#
# Player rick has 27 cards.
#
# Player morty has 25 cards.
# player1_card_value:  3
#
# player2_card_value:  11
#
#
# Round 44
#
# Player rick has 26 cards.
#
# Player morty has 26 cards.
# player1_card_value:  8
#
# player2_card_value:  8
#
# !!!!    AT WARRR    !!!!
#
#
# Player morty has 32 cards.
#
# Round 45
#
# Player rick has 20 cards.
#
# Player morty has 32 cards.
# player1_card_value:  6
#
# player2_card_value:  7
#
#
# Round 46
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  5
#
# player2_card_value:  8
#
#
# Round 47
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  9
#
# player2_card_value:  6
#
#
# Round 48
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  6
#
# player2_card_value:  13
#
#
# Round 49
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  14
#
# player2_card_value:  5
#
#
# Round 50
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  10
#
# player2_card_value:  12
#
#
# Round 51
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  14
#
# player2_card_value:  4
#
#
# Round 52
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  2
#
# player2_card_value:  9
#
#
# Round 53
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  4
#
# player2_card_value:  9
#
#
# Round 54
#
# Player rick has 17 cards.
#
# Player morty has 35 cards.
# player1_card_value:  3
#
# player2_card_value:  11
#
#
# Round 55
#
# Player rick has 16 cards.
#
# Player morty has 36 cards.
# player1_card_value:  12
#
# player2_card_value:  11
#
#
# Round 56
#
# Player rick has 17 cards.
#
# Player morty has 35 cards.
# player1_card_value:  2
#
# player2_card_value:  13
#
#
# Round 57
#
# Player rick has 16 cards.
#
# Player morty has 36 cards.
# player1_card_value:  12
#
# player2_card_value:  10
#
#
# Round 58
#
# Player rick has 17 cards.
#
# Player morty has 35 cards.
# player1_card_value:  7
#
# player2_card_value:  14
#
#
# Round 59
#
# Player rick has 16 cards.
#
# Player morty has 36 cards.
# player1_card_value:  7
#
# player2_card_value:  2
#
#
# Round 60
#
# Player rick has 17 cards.
#
# Player morty has 35 cards.
# player1_card_value:  4
#
# player2_card_value:  3
#
#
# Round 61
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  10
#
# player2_card_value:  8
#
#
# Round 62
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  9
#
# player2_card_value:  10
#
#
# Round 63
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  6
#
# player2_card_value:  3
#
#
# Round 64
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  2
#
# player2_card_value:  11
#
#
# Round 65
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  9
#
# player2_card_value:  8
#
#
# Round 66
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  6
#
# player2_card_value:  8
#
#
# Round 67
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  14
#
# player2_card_value:  5
#
#
# Round 68
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  5
#
# player2_card_value:  14
#
#
# Round 69
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  14
#
# player2_card_value:  13
#
#
# Round 70
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  4
#
# player2_card_value:  12
#
#
# Round 71
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  12
#
# player2_card_value:  4
#
#
# Round 72
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  11
#
# player2_card_value:  11
#
# !!!!    AT WARRR    !!!!
#
#
# Player morty has 39 cards.
#
# Round 73
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  3
#
# player2_card_value:  7
#
#
# Round 74
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  10
#
# player2_card_value:  5
#
#
# Round 75
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  8
#
# player2_card_value:  8
#
# !!!!    AT WARRR    !!!!
#
#
# Player rick has 19 cards.
#
# Round 76
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  5
#
# player2_card_value:  9
#
#
# Round 77
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  14
#
# player2_card_value:  4
#
#
# Round 78
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  13
#
# player2_card_value:  9
#
#
# Round 79
#
# Player rick has 20 cards.
#
# Player morty has 32 cards.
# player1_card_value:  12
#
# player2_card_value:  3
#
#
# Round 80
#
# Player rick has 21 cards.
#
# Player morty has 31 cards.
# player1_card_value:  4
#
# player2_card_value:  11
#
#
# Round 81
#
# Player rick has 20 cards.
#
# Player morty has 32 cards.
# player1_card_value:  10
#
# player2_card_value:  2
#
#
# Round 82
#
# Player rick has 21 cards.
#
# Player morty has 31 cards.
# player1_card_value:  5
#
# player2_card_value:  13
#
#
# Round 83
#
# Player rick has 20 cards.
#
# Player morty has 32 cards.
# player1_card_value:  8
#
# player2_card_value:  7
#
#
# Round 84
#
# Player rick has 21 cards.
#
# Player morty has 31 cards.
# player1_card_value:  8
#
# player2_card_value:  14
#
#
# Round 85
#
# Player rick has 20 cards.
#
# Player morty has 32 cards.
# player1_card_value:  6
#
# player2_card_value:  9
#
#
# Round 86
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  3
#
# player2_card_value:  10
#
#
# Round 87
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  9
#
# player2_card_value:  2
#
#
# Round 88
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  8
#
# player2_card_value:  11
#
#
# Round 89
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  14
#
# player2_card_value:  6
#
#
# Round 90
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  6
#
# player2_card_value:  8
#
#
# Round 91
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  13
#
# player2_card_value:  5
#
#
# Round 92
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  10
#
# player2_card_value:  14
#
#
# Round 93
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  12
#
# player2_card_value:  4
#
#
# Round 94
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  2
#
# player2_card_value:  12
#
#
# Round 95
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  14
#
# player2_card_value:  11
#
#
# Round 96
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  4
#
# player2_card_value:  11
#
#
# Round 97
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  13
#
# player2_card_value:  12
#
#
# Round 98
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  9
#
# player2_card_value:  10
#
#
# Round 99
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  12
#
# player2_card_value:  7
#
#
# Round 100
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  3
#
# player2_card_value:  2
#
#
# Round 101
#
# Player rick has 20 cards.
#
# Player morty has 32 cards.
# player1_card_value:  10
#
# player2_card_value:  4
#
#
# Round 102
#
# Player rick has 21 cards.
#
# Player morty has 31 cards.
# player1_card_value:  2
#
# player2_card_value:  3
#
#
# Round 103
#
# Player rick has 20 cards.
#
# Player morty has 32 cards.
# player1_card_value:  8
#
# player2_card_value:  13
#
#
# Round 104
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  7
#
# player2_card_value:  5
#
#
# Round 105
#
# Player rick has 20 cards.
#
# Player morty has 32 cards.
# player1_card_value:  9
#
# player2_card_value:  7
#
#
# Round 106
#
# Player rick has 21 cards.
#
# Player morty has 31 cards.
# player1_card_value:  2
#
# player2_card_value:  6
#
#
# Round 107
#
# Player rick has 20 cards.
#
# Player morty has 32 cards.
# player1_card_value:  14
#
# player2_card_value:  3
#
#
# Round 108
#
# Player rick has 21 cards.
#
# Player morty has 31 cards.
# player1_card_value:  6
#
# player2_card_value:  7
#
#
# Round 109
#
# Player rick has 20 cards.
#
# Player morty has 32 cards.
# player1_card_value:  13
#
# player2_card_value:  5
#
#
# Round 110
#
# Player rick has 21 cards.
#
# Player morty has 31 cards.
# player1_card_value:  5
#
# player2_card_value:  9
#
#
# Round 111
#
# Player rick has 20 cards.
#
# Player morty has 32 cards.
# player1_card_value:  12
#
# player2_card_value:  4
#
#
# Round 112
#
# Player rick has 21 cards.
#
# Player morty has 31 cards.
# player1_card_value:  4
#
# player2_card_value:  11
#
#
# Round 113
#
# Player rick has 20 cards.
#
# Player morty has 32 cards.
# player1_card_value:  14
#
# player2_card_value:  5
#
#
# Round 114
#
# Player rick has 21 cards.
#
# Player morty has 31 cards.
# player1_card_value:  11
#
# player2_card_value:  13
#
#
# Round 115
#
# Player rick has 20 cards.
#
# Player morty has 32 cards.
# player1_card_value:  13
#
# player2_card_value:  8
#
#
# Round 116
#
# Player rick has 21 cards.
#
# Player morty has 31 cards.
# player1_card_value:  12
#
# player2_card_value:  14
#
#
# Round 117
#
# Player rick has 20 cards.
#
# Player morty has 32 cards.
# player1_card_value:  12
#
# player2_card_value:  6
#
#
# Round 118
#
# Player rick has 21 cards.
#
# Player morty has 31 cards.
# player1_card_value:  7
#
# player2_card_value:  9
#
#
# Round 119
#
# Player rick has 20 cards.
#
# Player morty has 32 cards.
# player1_card_value:  3
#
# player2_card_value:  3
#
# !!!!    AT WARRR    !!!!
#
#
# Player morty has 38 cards.
#
# Round 120
#
# Player rick has 14 cards.
#
# Player morty has 38 cards.
# player1_card_value:  9
#
# player2_card_value:  10
#
#
# Round 121
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  7
#
# player2_card_value:  14
#
#
# Round 122
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  14
#
# player2_card_value:  2
#
#
# Round 123
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  3
#
# player2_card_value:  12
#
#
# Round 124
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  13
#
# player2_card_value:  4
#
#
# Round 125
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  5
#
# player2_card_value:  11
#
#
# Round 126
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  12
#
# player2_card_value:  9
#
#
# Round 127
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  4
#
# player2_card_value:  10
#
#
# Round 128
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  14
#
# player2_card_value:  2
#
#
# Round 129
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  5
#
# player2_card_value:  3
#
#
# Round 130
#
# Player rick has 14 cards.
#
# Player morty has 38 cards.
# player1_card_value:  13
#
# player2_card_value:  8
#
#
# Round 131
#
# Player rick has 15 cards.
#
# Player morty has 37 cards.
# player1_card_value:  8
#
# player2_card_value:  13
#
#
# Round 132
#
# Player rick has 14 cards.
#
# Player morty has 38 cards.
# player1_card_value:  12
#
# player2_card_value:  2
#
#
# Round 133
#
# Player rick has 15 cards.
#
# Player morty has 37 cards.
# player1_card_value:  6
#
# player2_card_value:  6
#
# !!!!    AT WARRR    !!!!
#
#
# Player rick has 21 cards.
#
# Round 134
#
# Player rick has 21 cards.
#
# Player morty has 31 cards.
# player1_card_value:  9
#
# player2_card_value:  11
#
#
# Round 135
#
# Player rick has 20 cards.
#
# Player morty has 32 cards.
# player1_card_value:  14
#
# player2_card_value:  11
#
#
# Round 136
#
# Player rick has 21 cards.
#
# Player morty has 31 cards.
# player1_card_value:  2
#
# player2_card_value:  13
#
#
# Round 137
#
# Player rick has 20 cards.
#
# Player morty has 32 cards.
# player1_card_value:  5
#
# player2_card_value:  12
#
#
# Round 138
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  3
#
# player2_card_value:  14
#
#
# Round 139
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  13
#
# player2_card_value:  7
#
#
# Round 140
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  8
#
# player2_card_value:  9
#
#
# Round 141
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  12
#
# player2_card_value:  3
#
#
# Round 142
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  2
#
# player2_card_value:  3
#
#
# Round 143
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  6
#
# player2_card_value:  2
#
#
# Round 144
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  6
#
# player2_card_value:  10
#
#
# Round 145
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  14
#
# player2_card_value:  4
#
#
# Round 146
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  2
#
# player2_card_value:  7
#
#
# Round 147
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  13
#
# player2_card_value:  5
#
#
# Round 148
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  4
#
# player2_card_value:  10
#
#
# Round 149
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  12
#
# player2_card_value:  8
#
#
# Round 150
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  6
#
# player2_card_value:  11
#
#
# Round 151
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  7
#
# player2_card_value:  6
#
#
# Round 152
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  5
#
# player2_card_value:  8
#
#
# Round 153
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  9
#
# player2_card_value:  9
#
# !!!!    AT WARRR    !!!!
#
#
# Player morty has 40 cards.
#
# Round 154
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  12
#
# player2_card_value:  5
#
#
# Round 155
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  3
#
# player2_card_value:  11
#
#
# Round 156
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  6
#
# player2_card_value:  4
#
#
# Round 157
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  2
#
# player2_card_value:  10
#
#
# Round 158
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  14
#
# player2_card_value:  8
#
#
# Round 159
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  4
#
# player2_card_value:  13
#
#
# Round 160
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  13
#
# player2_card_value:  9
#
#
# Round 161
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  5
#
# player2_card_value:  11
#
#
# Round 162
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  12
#
# player2_card_value:  2
#
#
# Round 163
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  8
#
# player2_card_value:  13
#
#
# Round 164
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  7
#
# player2_card_value:  5
#
#
# Round 165
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  6
#
# player2_card_value:  12
#
#
# Round 166
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  12
#
# player2_card_value:  3
#
#
# Round 167
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  5
#
# player2_card_value:  14
#
#
# Round 168
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  6
#
# player2_card_value:  8
#
#
# Round 169
#
# Player rick has 11 cards.
#
# Player morty has 41 cards.
# player1_card_value:  4
#
# player2_card_value:  9
#
#
# Round 170
#
# Player rick has 10 cards.
#
# Player morty has 42 cards.
# player1_card_value:  14
#
# player2_card_value:  2
#
#
# Round 171
#
# Player rick has 11 cards.
#
# Player morty has 41 cards.
# player1_card_value:  8
#
# player2_card_value:  3
#
#
# Round 172
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  13
#
# player2_card_value:  6
#
#
# Round 173
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  9
#
# player2_card_value:  10
#
#
# Round 174
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  12
#
# player2_card_value:  2
#
#
# Round 175
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  2
#
# player2_card_value:  7
#
#
# Round 176
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  7
#
# player2_card_value:  4
#
#
# Round 177
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  5
#
# player2_card_value:  10
#
#
# Round 178
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  12
#
# player2_card_value:  6
#
#
# Round 179
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  3
#
# player2_card_value:  11
#
#
# Round 180
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  14
#
# player2_card_value:  5
#
#
# Round 181
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  2
#
# player2_card_value:  8
#
#
# Round 182
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  8
#
# player2_card_value:  9
#
#
# Round 183
#
# Player rick has 11 cards.
#
# Player morty has 41 cards.
# player1_card_value:  3
#
# player2_card_value:  9
#
#
# Round 184
#
# Player rick has 10 cards.
#
# Player morty has 42 cards.
# player1_card_value:  13
#
# player2_card_value:  4
#
#
# Round 185
#
# Player rick has 11 cards.
#
# Player morty has 41 cards.
# player1_card_value:  6
#
# player2_card_value:  14
#
#
# Round 186
#
# Player rick has 10 cards.
#
# Player morty has 42 cards.
# player1_card_value:  12
#
# player2_card_value:  11
#
#
# Round 187
#
# Player rick has 11 cards.
#
# Player morty has 41 cards.
# player1_card_value:  2
#
# player2_card_value:  13
#
#
# Round 188
#
# Player rick has 10 cards.
#
# Player morty has 42 cards.
# player1_card_value:  7
#
# player2_card_value:  7
#
# !!!!    AT WARRR    !!!!
#
#
# Player morty has 48 cards.
#
# Round 189
#
# Player rick has 4 cards.
#
# Player morty has 48 cards.
# player1_card_value:  13
#
# player2_card_value:  3
#
#
# Round 190
#
# Player rick has 5 cards.
#
# Player morty has 47 cards.
# player1_card_value:  4
#
# player2_card_value:  11
#
#
# Round 191
#
# Player rick has 4 cards.
#
# Player morty has 48 cards.
# player1_card_value:  12
#
# player2_card_value:  2
#
#
# Round 192
#
# Player rick has 5 cards.
#
# Player morty has 47 cards.
# player1_card_value:  11
#
# player2_card_value:  10
#
#
# Round 193
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  13
#
# player2_card_value:  4
#
#
# Round 194
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  3
#
# player2_card_value:  13
#
#
# Round 195
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  12
#
# player2_card_value:  5
#
#
# Round 196
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  2
#
# player2_card_value:  11
#
#
# Round 197
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  11
#
# player2_card_value:  8
#
#
# Round 198
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  10
#
# player2_card_value:  13
#
#
# Round 199
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  13
#
# player2_card_value:  6
#
#
# Round 200
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  4
#
# player2_card_value:  12
#
#
# Round 201
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  12
#
# player2_card_value:  5
#
#
# Round 202
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  5
#
# player2_card_value:  14
#
#
# Round 203
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  11
#
# player2_card_value:  6
#
#
# Round 204
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  8
#
# player2_card_value:  8
#
# !!!!    AT WARRR    !!!!
#
#
# Player rick has 13 cards.
#
# Round 205
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  6
#
# player2_card_value:  7
#
#
# Round 206
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  8
#
# player2_card_value:  5
#
#
# Round 207
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  8
#
# player2_card_value:  10
#
#
# Round 208
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  13
#
# player2_card_value:  3
#
#
# Round 209
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  6
#
# player2_card_value:  11
#
#
# Round 210
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  12
#
# player2_card_value:  2
#
#
# Round 211
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  5
#
# player2_card_value:  8
#
#
# Round 212
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  11
#
# player2_card_value:  8
#
#
# Round 213
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  4
#
# player2_card_value:  9
#
#
# Round 214
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  9
#
# player2_card_value:  3
#
#
# Round 215
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  9
#
# player2_card_value:  9
#
# !!!!    AT WARRR    !!!!
#
#
# Player rick has 19 cards.
#
# Round 216
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  3
#
# player2_card_value:  7
#
#
# Round 217
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  12
#
# player2_card_value:  4
#
#
# Round 218
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  2
#
# player2_card_value:  12
#
#
# Round 219
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  11
#
# player2_card_value:  6
#
#
# Round 220
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  8
#
# player2_card_value:  14
#
#
# Round 221
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  9
#
# player2_card_value:  5
#
#
# Round 222
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  3
#
# player2_card_value:  10
#
#
# Round 223
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  9
#
# player2_card_value:  7
#
#
# Round 224
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  9
#
# player2_card_value:  14
#
#
# Round 225
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  10
#
# player2_card_value:  3
#
#
# Round 226
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  2
#
# player2_card_value:  12
#
#
# Round 227
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  8
#
# player2_card_value:  4
#
#
# Round 228
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  5
#
# player2_card_value:  11
#
#
# Round 229
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  13
#
# player2_card_value:  3
#
#
# Round 230
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  6
#
# player2_card_value:  13
#
#
# Round 231
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  14
#
# player2_card_value:  2
#
#
# Round 232
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  2
#
# player2_card_value:  11
#
#
# Round 233
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  13
#
# player2_card_value:  10
#
#
# Round 234
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  7
#
# player2_card_value:  13
#
#
# Round 235
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  12
#
# player2_card_value:  4
#
#
# Round 236
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  4
#
# player2_card_value:  12
#
#
# Round 237
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  11
#
# player2_card_value:  5
#
#
# Round 238
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  6
#
# player2_card_value:  14
#
#
# Round 239
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  9
#
# player2_card_value:  6
#
#
# Round 240
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  5
#
# player2_card_value:  7
#
#
# Round 241
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  9
#
# player2_card_value:  8
#
#
# Round 242
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  7
#
# player2_card_value:  10
#
#
# Round 243
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  10
#
# player2_card_value:  6
#
#
# Round 244
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  3
#
# player2_card_value:  11
#
#
# Round 245
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  8
#
# player2_card_value:  5
#
#
# Round 246
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  4
#
# player2_card_value:  8
#
#
# Round 247
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  13
#
# player2_card_value:  4
#
#
# Round 248
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  3
#
# player2_card_value:  9
#
#
# Round 249
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  14
#
# player2_card_value:  3
#
#
# Round 250
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  2
#
# player2_card_value:  7
#
#
# Round 251
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  13
#
# player2_card_value:  2
#
#
# Round 252
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  10
#
# player2_card_value:  12
#
#
# Round 253
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  12
#
# player2_card_value:  8
#
#
# Round 254
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  4
#
# player2_card_value:  14
#
#
# Round 255
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  11
#
# player2_card_value:  3
#
#
# Round 256
#
# Player rick has 19 cards.
#
# Player morty has 33 cards.
# player1_card_value:  5
#
# player2_card_value:  10
#
#
# Round 257
#
# Player rick has 18 cards.
#
# Player morty has 34 cards.
# player1_card_value:  9
#
# player2_card_value:  9
#
# !!!!    AT WARRR    !!!!
#
#
# Player morty has 40 cards.
#
# Round 258
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  8
#
# player2_card_value:  6
#
#
# Round 259
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  5
#
# player2_card_value:  13
#
#
# Round 260
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  13
#
# player2_card_value:  2
#
#
# Round 261
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  4
#
# player2_card_value:  11
#
#
# Round 262
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  14
#
# player2_card_value:  7
#
#
# Round 263
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  3
#
# player2_card_value:  13
#
#
# Round 264
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  13
#
# player2_card_value:  4
#
#
# Round 265
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  2
#
# player2_card_value:  12
#
#
# Round 266
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  12
#
# player2_card_value:  6
#
#
# Round 267
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  8
#
# player2_card_value:  14
#
#
# Round 268
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  11
#
# player2_card_value:  5
#
#
# Round 269
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  3
#
# player2_card_value:  7
#
#
# Round 270
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  8
#
# player2_card_value:  7
#
#
# Round 271
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  6
#
# player2_card_value:  10
#
#
# Round 272
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  13
#
# player2_card_value:  3
#
#
# Round 273
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  2
#
# player2_card_value:  11
#
#
# Round 274
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  14
#
# player2_card_value:  4
#
#
# Round 275
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  7
#
# player2_card_value:  8
#
#
# Round 276
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  13
#
# player2_card_value:  3
#
#
# Round 277
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  4
#
# player2_card_value:  9
#
#
# Round 278
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  12
#
# player2_card_value:  2
#
#
# Round 279
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  6
#
# player2_card_value:  7
#
#
# Round 280
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  11
#
# player2_card_value:  10
#
#
# Round 281
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  5
#
# player2_card_value:  12
#
#
# Round 282
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  8
#
# player2_card_value:  4
#
#
# Round 283
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  7
#
# player2_card_value:  14
#
#
# Round 284
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  13
#
# player2_card_value:  5
#
#
# Round 285
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  3
#
# player2_card_value:  10
#
#
# Round 286
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  14
#
# player2_card_value:  9
#
#
# Round 287
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  4
#
# player2_card_value:  9
#
#
# Round 288
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  13
#
# player2_card_value:  6
#
#
# Round 289
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  3
#
# player2_card_value:  9
#
#
# Round 290
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  12
#
# player2_card_value:  8
#
#
# Round 291
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  2
#
# player2_card_value:  10
#
#
# Round 292
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  11
#
# player2_card_value:  6
#
#
# Round 293
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  10
#
# player2_card_value:  14
#
#
# Round 294
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  8
#
# player2_card_value:  2
#
#
# Round 295
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  4
#
# player2_card_value:  12
#
#
# Round 296
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  13
#
# player2_card_value:  5
#
#
# Round 297
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  5
#
# player2_card_value:  11
#
#
# Round 298
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  14
#
# player2_card_value:  5
#
#
# Round 299
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  9
#
# player2_card_value:  13
#
#
# Round 300
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  13
#
# player2_card_value:  4
#
#
# Round 301
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  6
#
# player2_card_value:  11
#
#
# Round 302
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  12
#
# player2_card_value:  3
#
#
# Round 303
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  8
#
# player2_card_value:  13
#
#
# Round 304
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  11
#
# player2_card_value:  2
#
#
# Round 305
#
# Player rick has 13 cards.
#
# Player morty has 39 cards.
# player1_card_value:  6
#
# player2_card_value:  12
#
#
# Round 306
#
# Player rick has 12 cards.
#
# Player morty has 40 cards.
# player1_card_value:  8
#
# player2_card_value:  8
#
# !!!!    AT WARRR    !!!!
#
#
# Player morty has 46 cards.
#
# Round 307
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  13
#
# player2_card_value:  2
#
#
# Round 308
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  4
#
# player2_card_value:  11
#
#
# Round 309
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  12
#
# player2_card_value:  7
#
#
# Round 310
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  3
#
# player2_card_value:  8
#
#
# Round 311
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  11
#
# player2_card_value:  4
#
#
# Round 312
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  2
#
# player2_card_value:  9
#
#
# Round 313
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  13
#
# player2_card_value:  6
#
#
# Round 314
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  2
#
# player2_card_value:  7
#
#
# Round 315
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  12
#
# player2_card_value:  5
#
#
# Round 316
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  7
#
# player2_card_value:  12
#
#
# Round 317
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  11
#
# player2_card_value:  7
#
#
# Round 318
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  4
#
# player2_card_value:  14
#
#
# Round 319
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  13
#
# player2_card_value:  3
#
#
# Round 320
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  6
#
# player2_card_value:  10
#
#
# Round 321
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  12
#
# player2_card_value:  4
#
#
# Round 322
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  5
#
# player2_card_value:  9
#
#
# Round 323
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  11
#
# player2_card_value:  3
#
#
# Round 324
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  7
#
# player2_card_value:  9
#
#
# Round 325
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  13
#
# player2_card_value:  2
#
#
# Round 326
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  3
#
# player2_card_value:  10
#
#
# Round 327
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  12
#
# player2_card_value:  10
#
#
# Round 328
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  4
#
# player2_card_value:  14
#
#
# Round 329
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  11
#
# player2_card_value:  4
#
#
# Round 330
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  3
#
# player2_card_value:  12
#
#
# Round 331
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  13
#
# player2_card_value:  5
#
#
# Round 332
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  2
#
# player2_card_value:  11
#
#
# Round 333
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  12
#
# player2_card_value:  9
#
#
# Round 334
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  10
#
# player2_card_value:  13
#
#
# Round 335
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  11
#
# player2_card_value:  6
#
#
# Round 336
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  4
#
# player2_card_value:  11
#
#
# Round 337
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  13
#
# player2_card_value:  8
#
#
# Round 338
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  5
#
# player2_card_value:  13
#
#
# Round 339
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  12
#
# player2_card_value:  6
#
#
# Round 340
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  9
#
# player2_card_value:  12
#
#
# Round 341
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  11
#
# player2_card_value:  8
#
#
# Round 342
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  6
#
# player2_card_value:  8
#
#
# Round 343
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  13
#
# player2_card_value:  2
#
#
# Round 344
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  8
#
# player2_card_value:  13
#
#
# Round 345
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  12
#
# player2_card_value:  5
#
#
# Round 346
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  6
#
# player2_card_value:  14
#
#
# Round 347
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  11
#
# player2_card_value:  5
#
#
# Round 348
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  8
#
# player2_card_value:  14
#
#
# Round 349
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  13
#
# player2_card_value:  3
#
#
# Round 350
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  2
#
# player2_card_value:  7
#
#
# Round 351
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  12
#
# player2_card_value:  6
#
#
# Round 352
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  5
#
# player2_card_value:  10
#
#
# Round 353
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  11
#
# player2_card_value:  4
#
#
# Round 354
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  5
#
# player2_card_value:  11
#
#
# Round 355
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  13
#
# player2_card_value:  3
#
#
# Round 356
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  3
#
# player2_card_value:  8
#
#
# Round 357
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  12
#
# player2_card_value:  2
#
#
# Round 358
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  6
#
# player2_card_value:  9
#
#
# Round 359
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  11
#
# player2_card_value:  2
#
#
# Round 360
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  4
#
# player2_card_value:  7
#
#
# Round 361
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  13
#
# player2_card_value:  7
#
#
# Round 362
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  3
#
# player2_card_value:  12
#
#
# Round 363
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  12
#
# player2_card_value:  4
#
#
# Round 364
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  2
#
# player2_card_value:  14
#
#
# Round 365
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  11
#
# player2_card_value:  6
#
#
# Round 366
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  2
#
# player2_card_value:  10
#
#
# Round 367
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  13
#
# player2_card_value:  5
#
#
# Round 368
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  7
#
# player2_card_value:  9
#
#
# Round 369
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  12
#
# player2_card_value:  7
#
#
# Round 370
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  4
#
# player2_card_value:  9
#
#
# Round 371
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  11
#
# player2_card_value:  3
#
#
# Round 372
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  6
#
# player2_card_value:  10
#
#
# Round 373
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  13
#
# player2_card_value:  4
#
#
# Round 374
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  5
#
# player2_card_value:  14
#
#
# Round 375
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  12
#
# player2_card_value:  3
#
#
# Round 376
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  7
#
# player2_card_value:  12
#
#
# Round 377
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  11
#
# player2_card_value:  2
#
#
# Round 378
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  3
#
# player2_card_value:  11
#
#
# Round 379
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  13
#
# player2_card_value:  10
#
#
# Round 380
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  4
#
# player2_card_value:  13
#
#
# Round 381
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  12
#
# player2_card_value:  4
#
#
# Round 382
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  3
#
# player2_card_value:  11
#
#
# Round 383
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  11
#
# player2_card_value:  5
#
#
# Round 384
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  2
#
# player2_card_value:  13
#
#
# Round 385
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  13
#
# player2_card_value:  9
#
#
# Round 386
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  10
#
# player2_card_value:  12
#
#
# Round 387
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  12
#
# player2_card_value:  6
#
#
# Round 388
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  4
#
# player2_card_value:  8
#
#
# Round 389
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  11
#
# player2_card_value:  8
#
#
# Round 390
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  5
#
# player2_card_value:  13
#
#
# Round 391
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  13
#
# player2_card_value:  6
#
#
# Round 392
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  9
#
# player2_card_value:  14
#
#
# Round 393
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  12
#
# player2_card_value:  8
#
#
# Round 394
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  6
#
# player2_card_value:  14
#
#
# Round 395
#
# Player rick has 6 cards.
#
# Player morty has 46 cards.
# player1_card_value:  11
#
# player2_card_value:  2
#
#
# Round 396
#
# Player rick has 7 cards.
#
# Player morty has 45 cards.
# player1_card_value:  8
#
# player2_card_value:  7
#
#
# Round 397
#
# Player rick has 8 cards.
#
# Player morty has 44 cards.
# player1_card_value:  13
#
# player2_card_value:  5
#
#
# Round 398
#
# Player rick has 9 cards.
#
# Player morty has 43 cards.
# player1_card_value:  6
#
# player2_card_value:  10
#
#
# Round 399
#
# Player rick has 8 cards.
#
# Player morty has 44 cards.
# player1_card_value:  12
#
# player2_card_value:  5
#
#
# Round 400
#
# Player rick has 9 cards.
#
# Player morty has 43 cards.
# player1_card_value:  8
#
# player2_card_value:  11
#
#
# Round 401
#
# Player rick has 8 cards.
#
# Player morty has 44 cards.
# player1_card_value:  11
#
# player2_card_value:  3
#
#
# Round 402
#
# Player rick has 9 cards.
#
# Player morty has 43 cards.
# player1_card_value:  2
#
# player2_card_value:  8
#
#
# Round 403
#
# Player rick has 8 cards.
#
# Player morty has 44 cards.
# player1_card_value:  8
#
# player2_card_value:  6
#
#
# Round 404
#
# Player rick has 9 cards.
#
# Player morty has 43 cards.
# player1_card_value:  7
#
# player2_card_value:  9
#
#
# Round 405
#
# Player rick has 8 cards.
#
# Player morty has 44 cards.
# player1_card_value:  13
#
# player2_card_value:  4
#
#
# Round 406
#
# Player rick has 9 cards.
#
# Player morty has 43 cards.
# player1_card_value:  5
#
# player2_card_value:  7
#
#
# Round 407
#
# Player rick has 8 cards.
#
# Player morty has 44 cards.
# player1_card_value:  12
#
# player2_card_value:  3
#
#
# Round 408
#
# Player rick has 9 cards.
#
# Player morty has 43 cards.
# player1_card_value:  5
#
# player2_card_value:  12
#
#
# Round 409
#
# Player rick has 8 cards.
#
# Player morty has 44 cards.
# player1_card_value:  11
#
# player2_card_value:  2
#
#
# Round 410
#
# Player rick has 9 cards.
#
# Player morty has 43 cards.
# player1_card_value:  3
#
# player2_card_value:  14
#
#
# Round 411
#
# Player rick has 8 cards.
#
# Player morty has 44 cards.
# player1_card_value:  8
#
# player2_card_value:  2
#
#
# Round 412
#
# Player rick has 9 cards.
#
# Player morty has 43 cards.
# player1_card_value:  6
#
# player2_card_value:  10
#
#
# Round 413
#
# Player rick has 8 cards.
#
# Player morty has 44 cards.
# player1_card_value:  13
#
# player2_card_value:  7
#
#
# Round 414
#
# Player rick has 9 cards.
#
# Player morty has 43 cards.
# player1_card_value:  4
#
# player2_card_value:  9
#
#
# Round 415
#
# Player rick has 8 cards.
#
# Player morty has 44 cards.
# player1_card_value:  12
#
# player2_card_value:  4
#
#
# Round 416
#
# Player rick has 9 cards.
#
# Player morty has 43 cards.
# player1_card_value:  3
#
# player2_card_value:  9
#
#
# Round 417
#
# Player rick has 8 cards.
#
# Player morty has 44 cards.
# player1_card_value:  11
#
# player2_card_value:  6
#
#
# Round 418
#
# Player rick has 9 cards.
#
# Player morty has 43 cards.
# player1_card_value:  2
#
# player2_card_value:  10
#
#
# Round 419
#
# Player rick has 8 cards.
#
# Player morty has 44 cards.
# player1_card_value:  8
#
# player2_card_value:  5
#
#
# Round 420
#
# Player rick has 9 cards.
#
# Player morty has 43 cards.
# player1_card_value:  2
#
# player2_card_value:  14
#
#
# Round 421
#
# Player rick has 8 cards.
#
# Player morty has 44 cards.
# player1_card_value:  13
#
# player2_card_value:  7
#
#
# Round 422
#
# Player rick has 9 cards.
#
# Player morty has 43 cards.
# player1_card_value:  7
#
# player2_card_value:  12
#
#
# Round 423
#
# Player rick has 8 cards.
#
# Player morty has 44 cards.
# player1_card_value:  12
#
# player2_card_value:  3
#
#
# Round 424
#
# Player rick has 9 cards.
#
# Player morty has 43 cards.
# player1_card_value:  4
#
# player2_card_value:  11
#
#
# Round 425
#
# Player rick has 8 cards.
#
# Player morty has 44 cards.
# player1_card_value:  11
#
# player2_card_value:  4
#
#
# Round 426
#
# Player rick has 9 cards.
#
# Player morty has 43 cards.
# player1_card_value:  6
#
# player2_card_value:  13
#
#
# Round 427
#
# Player rick has 8 cards.
#
# Player morty has 44 cards.
# player1_card_value:  8
#
# player2_card_value:  3
#
#
# Round 428
#
# Player rick has 9 cards.
#
# Player morty has 43 cards.
# player1_card_value:  5
#
# player2_card_value:  11
#
#
# Round 429
#
# Player rick has 8 cards.
#
# Player morty has 44 cards.
# player1_card_value:  13
#
# player2_card_value:  2
#
#
# Round 430
#
# Player rick has 9 cards.
#
# Player morty has 43 cards.
# player1_card_value:  7
#
# player2_card_value:  13
#
#
# Round 431
#
# Player rick has 8 cards.
#
# Player morty has 44 cards.
# player1_card_value:  12
#
# player2_card_value:  10
#
#
# Round 432
#
# Player rick has 9 cards.
#
# Player morty has 43 cards.
# player1_card_value:  3
#
# player2_card_value:  12
#
#
# Round 433
#
# Player rick has 8 cards.
#
# Player morty has 44 cards.
# player1_card_value:  11
#
# player2_card_value:  4
#
#
# Round 434
#
# Player rick has 9 cards.
#
# Player morty has 43 cards.
# player1_card_value:  4
#
# player2_card_value:  8
#
#
# Round 435
#
# Player rick has 8 cards.
#
# Player morty has 44 cards.
# player1_card_value:  8
#
# player2_card_value:  5
#
#
# Round 436
#
# Player rick has 9 cards.
#
# Player morty has 43 cards.
# player1_card_value:  3
#
# player2_card_value:  13
#
#
# Round 437
#
# Player rick has 8 cards.
#
# Player morty has 44 cards.
# player1_card_value:  13
#
# player2_card_value:  9
#
#
# Round 438
#
# Player rick has 9 cards.
#
# Player morty has 43 cards.
# player1_card_value:  2
#
# player2_card_value:  14
#
#
# Round 439
#
# Player rick has 8 cards.
#
# Player morty has 44 cards.
# player1_card_value:  12
#
# player2_card_value:  6
#
#
# Round 440
#
# Player rick has 9 cards.
#
# Player morty has 43 cards.
# player1_card_value:  10
#
# player2_card_value:  14
#
#
# Round 441
#
# Player rick has 8 cards.
#
# Player morty has 44 cards.
# player1_card_value:  11
#
# player2_card_value:  6
#
#
# Round 442
#
# Player rick has 9 cards.
#
# Player morty has 43 cards.
# player1_card_value:  4
#
# player2_card_value:  10
#
#
# Round 443
#
# Player rick has 8 cards.
#
# Player morty has 44 cards.
# player1_card_value:  8
#
# player2_card_value:  8
#
# !!!!    AT WARRR    !!!!
#
#
# Player morty has 50 cards.
#
# Round 444
#
# Player rick has 2 cards.
#
# Player morty has 50 cards.
# player1_card_value:  11
#
# player2_card_value:  5
#
#
# Round 445
#
# Player rick has 3 cards.
#
# Player morty has 49 cards.
# player1_card_value:  6
#
# player2_card_value:  7
#
#
# Round 446
#
# Player rick has 2 cards.
#
# Player morty has 50 cards.
# player1_card_value:  11
#
# player2_card_value:  5
#
#
# Round 447
#
# Player rick has 3 cards.
#
# Player morty has 49 cards.
# player1_card_value:  5
#
# player2_card_value:  12
#
#
# Round 448
#
# Player rick has 2 cards.
#
# Player morty has 50 cards.
# player1_card_value:  11
#
# player2_card_value:  3
#
#
# Round 449
#
# Player rick has 3 cards.
#
# Player morty has 49 cards.
# player1_card_value:  5
#
# player2_card_value:  14
#
#
# Round 450
#
# Player rick has 2 cards.
#
# Player morty has 50 cards.
# player1_card_value:  11
#
# player2_card_value:  6
#
#
# Round 451
#
# Player rick has 3 cards.
#
# Player morty has 49 cards.
# player1_card_value:  3
#
# player2_card_value:  10
#
#
# Round 452
#
# Player rick has 2 cards.
#
# Player morty has 50 cards.
# player1_card_value:  11
#
# player2_card_value:  4
#
#
# Round 453
#
# Player rick has 3 cards.
#
# Player morty has 49 cards.
# player1_card_value:  6
#
# player2_card_value:  9
#
#
# Round 454
#
# Player rick has 2 cards.
#
# Player morty has 50 cards.
# player1_card_value:  11
#
# player2_card_value:  3
#
#
# Round 455
#
# Player rick has 3 cards.
#
# Player morty has 49 cards.
# player1_card_value:  4
#
# player2_card_value:  9
#
#
# Round 456
#
# Player rick has 2 cards.
#
# Player morty has 50 cards.
# player1_card_value:  11
#
# player2_card_value:  2
#
#
# Round 457
#
# Player rick has 3 cards.
#
# Player morty has 49 cards.
# player1_card_value:  3
#
# player2_card_value:  10
#
#
# Round 458
#
# Player rick has 2 cards.
#
# Player morty has 50 cards.
# player1_card_value:  11
#
# player2_card_value:  2
#
#
# Round 459
#
# Player rick has 3 cards.
#
# Player morty has 49 cards.
# player1_card_value:  2
#
# player2_card_value:  14
#
#
# Round 460
#
# Player rick has 2 cards.
#
# Player morty has 50 cards.
# player1_card_value:  11
#
# player2_card_value:  7
#
#
# Round 461
#
# Player rick has 3 cards.
#
# Player morty has 49 cards.
# player1_card_value:  2
#
# player2_card_value:  12
#
#
# Round 462
#
# Player rick has 2 cards.
#
# Player morty has 50 cards.
# player1_card_value:  11
#
# player2_card_value:  4
#
#
# Round 463
#
# Player rick has 3 cards.
#
# Player morty has 49 cards.
# player1_card_value:  7
#
# player2_card_value:  11
#
#
# Round 464
#
# Player rick has 2 cards.
#
# Player morty has 50 cards.
# player1_card_value:  11
#
# player2_card_value:  6
#
#
# Round 465
#
# Player rick has 3 cards.
#
# Player morty has 49 cards.
# player1_card_value:  4
#
# player2_card_value:  13
#
#
# Round 466
#
# Player rick has 2 cards.
#
# Player morty has 50 cards.
# player1_card_value:  11
#
# player2_card_value:  5
#
#
# Round 467
#
# Player rick has 3 cards.
#
# Player morty has 49 cards.
# player1_card_value:  6
#
# player2_card_value:  11
#
#
# Round 468
#
# Player rick has 2 cards.
#
# Player morty has 50 cards.
# player1_card_value:  11
#
# player2_card_value:  7
#
#
# Round 469
#
# Player rick has 3 cards.
#
# Player morty has 49 cards.
# player1_card_value:  5
#
# player2_card_value:  13
#
#
# Round 470
#
# Player rick has 2 cards.
#
# Player morty has 50 cards.
# player1_card_value:  11
#
# player2_card_value:  3
#
#
# Round 471
#
# Player rick has 3 cards.
#
# Player morty has 49 cards.
# player1_card_value:  7
#
# player2_card_value:  12
#
#
# Round 472
#
# Player rick has 2 cards.
#
# Player morty has 50 cards.
# player1_card_value:  11
#
# player2_card_value:  4
#
#
# Round 473
#
# Player rick has 3 cards.
#
# Player morty has 49 cards.
# player1_card_value:  3
#
# player2_card_value:  8
#
#
# Round 474
#
# Player rick has 2 cards.
#
# Player morty has 50 cards.
# player1_card_value:  11
#
# player2_card_value:  3
#
#
# Round 475
#
# Player rick has 3 cards.
#
# Player morty has 49 cards.
# player1_card_value:  4
#
# player2_card_value:  13
#
#
# Round 476
#
# Player rick has 2 cards.
#
# Player morty has 50 cards.
# player1_card_value:  11
#
# player2_card_value:  2
#
#
# Round 477
#
# Player rick has 3 cards.
#
# Player morty has 49 cards.
# player1_card_value:  3
#
# player2_card_value:  14
#
#
# Round 478
#
# Player rick has 2 cards.
#
# Player morty has 50 cards.
# player1_card_value:  11
#
# player2_card_value:  10
#
#
# Round 479
#
# Player rick has 3 cards.
#
# Player morty has 49 cards.
# player1_card_value:  2
#
# player2_card_value:  14
#
#
# Round 480
#
# Player rick has 2 cards.
#
# Player morty has 50 cards.
# player1_card_value:  11
#
# player2_card_value:  4
#
#
# Round 481
#
# Player rick has 3 cards.
#
# Player morty has 49 cards.
# player1_card_value:  10
#
# player2_card_value:  10
#
# !!!!    AT WARRR    !!!!
# Player 1 out of cards Player 2 morty Wins!
