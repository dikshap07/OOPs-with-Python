# %% [markdown]
# <a href="https://colab.research.google.com/github/dikshap07/OOPs-with-Python/blob/master/war_game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

suits = ['Hearts','Clubs','Spades','Diamonds']

ranks = ['Two','Three','Four','Five','Six','Seven','Eight','Nine','Ten','Jack','Queen','King','Ace']

values = {'Two': 2, 'Three': 3, 'Four': 4, 'Five': 5, 'Six' : 6 , 'Seven' :7, 'Eight': 8,'Nine':9,
          'Ten':10,'Jack':11, 'Queen': 12,'King': 13,'Ace':14 }

# %%
class Card():  
    
    
    def __init__(self,suit,rank):
        
        self.suit = suit
        self.rank = rank
        self.value = values[rank]
    
    #string method
    def __str__(self):
        
        return self.rank + ' of ' + self.suit

# %%
class Deck():

  def __init__(self):

    self.all_cards = []  #list of objects

    for suit in suits:

      for rank in ranks:
        #create card object

        created_card = Card(suit,rank)

        self.all_cards.append(created_card)


  def shuffle(self):   #method to shuffle the card

    random.shuffle(self.all_cards)



  def deal_one(self):

    return self.all_cards.pop()  #we want the last card from deck

# %%
new_deck = Deck()

# %%
first_card = new_deck.all_cards[0]

# %%
#deck is in order
for card_object in new_deck.all_cards:

  print(card_object)
# Out:
# Two of Hearts
# Three of Hearts
# Four of Hearts
# Five of Hearts
# Six of Hearts
# Seven of Hearts
# Eight of Hearts
# Nine of Hearts
# Ten of Hearts
# Jack of Hearts
# Queen of Hearts
# King of Hearts
# Ace of Hearts
# Two of Clubs
# Three of Clubs
# Four of Clubs
# Five of Clubs
# Six of Clubs
# Seven of Clubs
# Eight of Clubs
# Nine of Clubs
# Ten of Clubs
# Jack of Clubs
# Queen of Clubs
# King of Clubs
# Ace of Clubs
# Two of Spades
# Three of Spades
# Four of Spades
# Five of Spades
# Six of Spades
# Seven of Spades
# Eight of Spades
# Nine of Spades
# Ten of Spades
# Jack of Spades
# Queen of Spades
# King of Spades
# Ace of Spades
# Two of Diamonds
# Three of Diamonds
# Four of Diamonds
# Five of Diamonds
# Six of Diamonds
# Seven of Diamonds
# Eight of Diamonds
# Nine of Diamonds
# Ten of Diamonds
# Jack of Diamonds
# Queen of Diamonds
# King of Diamonds
# Ace of Diamonds

# %%
#shuffle the deck

new_deck.shuffle()

# %%
#now the deck is not in order
for card_object in new_deck.all_cards:

  print(card_object)
# Out:
# Ace of Hearts
# Three of Spades
# Ace of Diamonds
# Three of Diamonds
# Nine of Spades
# Seven of Spades
# Two of Spades
# Two of Diamonds
# Five of Clubs
# Nine of Clubs
# Eight of Spades
# Five of Hearts
# Ace of Clubs
# Six of Clubs
# Seven of Hearts
# King of Spades
# Eight of Hearts
# Five of Spades
# Jack of Clubs
# Queen of Clubs
# Queen of Hearts
# King of Diamonds
# Jack of Diamonds
# Four of Diamonds
# Eight of Clubs
# King of Hearts
# Jack of Spades
# Queen of Spades
# Ten of Clubs
# Eight of Diamonds
# Two of Hearts
# Ace of Spades
# Nine of Hearts
# Ten of Spades
# Four of Hearts
# Six of Spades
# Nine of Diamonds
# Three of Clubs
# Three of Hearts
# Ten of Diamonds
# Five of Diamonds
# Queen of Diamonds
# Six of Hearts
# Four of Clubs
# Six of Diamonds
# Seven of Diamonds
# Seven of Clubs
# Jack of Hearts
# Ten of Hearts
# Four of Spades
# King of Clubs
# Two of Clubs

# %%
#to get the last card from the deck and then remove it from the list
mycard = new_deck.deal_one()
print(mycard)
# Out:
# Two of Clubs

# %%
len(new_deck.all_cards)
# Out:
# 51

# %%
#player class

#used to hold a player's current list of cards
#player should be able to add or remove cards from their hands
#player shoyld be able to add single or mulitple cards to their list of card objects
class Player():

  def __init__(self,name):

    self.name  = name
    self.all_cards = []

  def remove_one(self):

    return self.all_cards.pop(0)    #to remove card from beginning of the list

    

  def add_cards(self,new_cards):


    if type(new_cards) == type([]):

      self.all_cards.extend(new_cards)

    else:

      self.all_cards.append(new_cards)

  def __str__(self):
    return f'Player {self.name} has {len(self.all_cards)} cards.'

# %%
new_player = Player('Jose')

# %%
print(new_player)
# Out:
# Player Jose has 0 cards.

# %%
new_player.add_cards(new_deck.all_cards)

# %%
player1_name = input('Enter the name of Player1: ')

player2_name = input('Enter the name of Player2: ')

player1 = Player(player1_name)
player2 = Player(player2_name)
newdeck = Deck()
newdeck.shuffle()

#splitting the deck among the two players - alternate card from deck goes to each player respectively

for i in range(0,len(newdeck.all_cards)-1,2):  

  player1.add_cards(newdeck.all_cards[i])
  player2.add_cards(newdeck.all_cards[i+1])


print(player1)
print(player2)
# Out:
# Enter the name of Player1: rick
# Enter the name of Player2: morty
# Player rick has 26 cards.
# Player morty has 26 cards.

# %%
print(player1)
print(player2)

player1_card = player1.remove_one()
player2_card = player2.remove_one()
print('player1_card',player1_card.value)
print('player2_card',player2_card.value)

if player1_card.value > player2_card.value:

  player1.add_cards(player1_card)
  player1.add_cards(player2_card)

  print('p1>p2', player1)

elif player2_card.value > player1_card.value:

  player2.add_cards(player2_card)
  player2.add_cards(player1_card)

  print('p2>p1',player2)

else:
  player1_list = []
  player2_list = []
  for i in range(3):

    if player1.all_cards != [] and player2.all_cards != []:

      player1_list.append(player1.remove_one())
      player2_list.append(player2.remove_one())

    elif player1.all_cards == [] or player2.all_cards == []:

      break

  print('player1_list',player1_list)
  print('player2_list',player2_list)
        
  if player1_list[-1].value > player2_list[-1].value:

    player1.add_cards(player1_list)
    player1.add_cards(player2_list)
           
  elif player1_list[-1].value < player2_list[-1].value:

    player2.add_cards(player2_list)
    player2.add_cards(player1_list)
# Out:
# Player rick has 23 cards.
# Player morty has 27 cards.
# player1_card 5
# player2_card 7
# p2>p1 Player morty has 28 cards.

# %% [markdown]
# GAMELOGIC

# %%
#create 2 new instances of the player class

player1_name = input('Enter the name of Player1: ')

player2_name = input('Enter the name of Player2: ')

player1 = Player(player1_name)
player2 = Player(player2_name)
newdeck = Deck()
newdeck.shuffle()

#splitting the deck among the two players - alternate card from deck goes to each player respectively

#for i in range(0,len(newdeck.all_cards)-1,2):  

 # player1.add_cards(newdeck.all_cards[i])
  #player2.add_cards(newdeck.all_cards[i+1])

for x in range(26):

  player1.add_cards(newdeck.deal_one())
  player2.add_cards(newdeck.deal_one())

print(player1)
print(player2)


game_status = True
    
round_num = 0
while game_status == True:

  round_num +=1
  print(f"Round {round_num}")


  if len(player1.all_cards) == 0:

    print('Player 1 out of cards'+ player2.name + 'Wins!')
    game_status = False
    break
  
  if len(player2.all_cards) == 0:

    print('Player 2 out of cards' + player1.name + 'Wins!')
    game_status = False
    break


  else:

      
    player1_cards = []
    player1_cards.append(player1.remove_one())
    player2_cards = []
    player2_cards.append(player2.remove_one())

    print('player1_card_value: ',player1_card.value)
    print('')
    print('player2_card_value: ',player2_card.value)
    print('')
    print(player1)
    print('')
    print(player2)


    if player1_cards[-1].value > player2_cards[-1].value:

      player1.add_cards(player1_cards)
      player1.add_cards(player2_cards)

      #print('p1>p2', player1)

    elif player2_cards[-1].value > player1_cards[-1].value:

      player2.add_cards(player2_cards)
      player2.add_cards(player1_cards)

      #print('p2>p1',player2)
      
    else:      

      war_x = True
      inner_while = 0

      while war_x == True and game_status == True:  #we will make the players draw 3 cards if both cards are equal
        player1_list = []
        player2_list = []

        inner_while+=1
        print('Inner while loop count',inner_while)

        
        for i in range(3):

          if player1.all_cards != [] and player2.all_cards != []:

            player1_list.append(player1.remove_one())
            player2_list.append(player2.remove_one())

          elif player1.all_cards == [] or player2.all_cards == []:

            game_status = False
            break

        print('player1_list',player1_list)
        print('player2_list',player2_list)
        
        if player1_list[-1].value > player2_list[-1].value:

          player1.add_cards(player1_list)
          player1.add_cards(player2_list)
          war_x = False      
                  
        
        elif player1_list[-1].value < player2_list[-1].value:

          player2.add_cards(player2_list)
          player2.add_cards(player1_list)
          war_x = False
          
        
        else: 
          war_x = True     

     
print(player1)
print(player2)

if len(player1.all_cards) == 0:
  print('Player 2 won')

elif len(player2.all_cards) == 0:
  print('Player 1 won')
# Out:
# Enter the name of Player1: rick
# Enter the name of Player2: morty
# Player rick has 26 cards.
# Player morty has 26 cards.
# Round 1
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 25 cards.
#
# Player morty has 25 cards.
# Round 2
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 24 cards.
#
# Player morty has 26 cards.
# Round 3
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 25 cards.
#
# Player morty has 25 cards.
# Round 4
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 26 cards.
#
# Player morty has 24 cards.
# Round 5
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 27 cards.
#
# Player morty has 23 cards.
# Round 6
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 26 cards.
#
# Player morty has 24 cards.
# Round 7
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 27 cards.
#
# Player morty has 23 cards.
# Round 8
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 26 cards.
#
# Player morty has 24 cards.
# Round 9
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 27 cards.
#
# Player morty has 23 cards.
# Round 10
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 26 cards.
#
# Player morty has 24 cards.
# Round 11
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 25 cards.
#
# Player morty has 25 cards.
# Round 12
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 24 cards.
#
# Player morty has 26 cards.
# Round 13
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 25 cards.
#
# Player morty has 25 cards.
# Round 14
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 26 cards.
#
# Player morty has 24 cards.
# Round 15
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 25 cards.
#
# Player morty has 25 cards.
# Round 16
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 26 cards.
#
# Player morty has 24 cards.
# Inner while loop count 1
# player1_list [<__main__.Card object at 0x7f504c070d10>, <__main__.Card object at 0x7f504c0492d0>, <__main__.Card object at 0x7f504c07d310>]
# player2_list [<__main__.Card object at 0x7f504c07d610>, <__main__.Card object at 0x7f504c051090>, <__main__.Card object at 0x7f504c07dc50>]
# Round 17
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 28 cards.
#
# Player morty has 20 cards.
# Round 18
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 27 cards.
#
# Player morty has 21 cards.
# Round 19
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 28 cards.
#
# Player morty has 20 cards.
# Inner while loop count 1
# player1_list [<__main__.Card object at 0x7f504c04fb90>, <__main__.Card object at 0x7f504c04fbd0>, <__main__.Card object at 0x7f504c07d450>]
# player2_list [<__main__.Card object at 0x7f504c051050>, <__main__.Card object at 0x7f504c07d1d0>, <__main__.Card object at 0x7f504c07d5d0>]
# Round 20
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 24 cards.
#
# Player morty has 22 cards.
# Round 21
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 23 cards.
#
# Player morty has 23 cards.
# Round 22
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 22 cards.
#
# Player morty has 24 cards.
# Round 23
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 21 cards.
#
# Player morty has 25 cards.
# Round 24
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 20 cards.
#
# Player morty has 26 cards.
# Inner while loop count 1
# player1_list [<__main__.Card object at 0x7f504c07ddd0>, <__main__.Card object at 0x7f504c07d390>, <__main__.Card object at 0x7f504c04f950>]
# player2_list [<__main__.Card object at 0x7f504c07d150>, <__main__.Card object at 0x7f504c07d550>, <__main__.Card object at 0x7f504c07dfd0>]
# Round 25
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 16 cards.
#
# Player morty has 28 cards.
# Round 26
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 15 cards.
#
# Player morty has 29 cards.
# Round 27
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 16 cards.
#
# Player morty has 28 cards.
# Round 28
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 15 cards.
#
# Player morty has 29 cards.
# Round 29
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 14 cards.
#
# Player morty has 30 cards.
# Inner while loop count 1
# player1_list [<__main__.Card object at 0x7f504c07d290>, <__main__.Card object at 0x7f504c070490>, <__main__.Card object at 0x7f504c07d210>]
# player2_list [<__main__.Card object at 0x7f504c07d350>, <__main__.Card object at 0x7f504c07df90>, <__main__.Card object at 0x7f504c051110>]
# Inner while loop count 2
# player1_list [<__main__.Card object at 0x7f504c07d4d0>, <__main__.Card object at 0x7f504c070d10>, <__main__.Card object at 0x7f504c0492d0>]
# player2_list [<__main__.Card object at 0x7f504c07ce50>, <__main__.Card object at 0x7f504c051050>, <__main__.Card object at 0x7f504c07d1d0>]
# Round 30
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 13 cards.
#
# Player morty has 23 cards.
# Round 31
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 12 cards.
#
# Player morty has 24 cards.
# Round 32
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 11 cards.
#
# Player morty has 25 cards.
# Round 33
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 12 cards.
#
# Player morty has 24 cards.
# Round 34
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 11 cards.
#
# Player morty has 25 cards.
# Round 35
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 10 cards.
#
# Player morty has 26 cards.
# Round 36
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 9 cards.
#
# Player morty has 27 cards.
# Round 37
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 8 cards.
#
# Player morty has 28 cards.
# Round 38
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 7 cards.
#
# Player morty has 29 cards.
# Round 39
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 8 cards.
#
# Player morty has 28 cards.
# Round 40
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 9 cards.
#
# Player morty has 27 cards.
# Round 41
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 8 cards.
#
# Player morty has 28 cards.
# Round 42
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 9 cards.
#
# Player morty has 27 cards.
# Round 43
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 10 cards.
#
# Player morty has 26 cards.
# Round 44
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 9 cards.
#
# Player morty has 27 cards.
# Round 45
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 8 cards.
#
# Player morty has 28 cards.
# Round 46
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 7 cards.
#
# Player morty has 29 cards.
# Round 47
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 8 cards.
#
# Player morty has 28 cards.
# Round 48
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 7 cards.
#
# Player morty has 29 cards.
# Round 49
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 6 cards.
#
# Player morty has 30 cards.
# Round 50
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 5 cards.
#
# Player morty has 31 cards.
# Round 51
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 4 cards.
#
# Player morty has 32 cards.
# Round 52
# player1_card_value:  11
#
# player2_card_value:  2
#
# Player rick has 3 cards.
#
# Player morty has 33 cards.
# Inner while loop count 1
# player1_list [<__main__.Card object at 0x7f504c07d150>, <__main__.Card object at 0x7f504c07d4d0>, <__main__.Card object at 0x7f504c07d390>]
# player2_list [<__main__.Card object at 0x7f504c04f6d0>, <__main__.Card object at 0x7f504c07d5d0>, <__main__.Card object at 0x7f504c07d310>]
# Round 53
# Player 1 out of cardsmortyWins!
# Player rick has 0 cards.
# Player morty has 36 cards.
# Player 2 won

# %%
k#create 2 new instances of the player class

player1_name = input('Enter the name of Player1: ')

player2_name = input('Enter the name of Player2: ')

player1 = Player(player1_name)
player2 = Player(player2_name)
newdeck = Deck()
newdeck.shuffle()

#splitting the deck among the two players - alternate card from deck goes to each player respectively

for i in range(0,len(newdeck.all_cards)-1,2):  

  player1.add_cards(newdeck.all_cards[i])
  player2.add_cards(newdeck.all_cards[i+1])


print(player1)
print(player2)


if len(player1.all_cards) != 0 or len(player2.all_cards) != 0:
    game_status = True
    

while game_status == True:


  if len(player1.all_cards) == 0 or len(player2.all_cards) == 0:
    game_status = False


  else:

      
    player1_card = player1.remove_one()
    player2_card = player2.remove_one()
    print('player1_card_value: ',player1_card.value)
    print('')
    print('player2_card_value: ',player2_card.value)
    print('')
    print(player1)
    print('')
    print(player2)


    if player1_card.value > player2_card.value:

      player1.add_cards(player1_card)
      player1.add_cards(player2_card)

      print('p1>p2', player1)

    elif player2_card.value > player1_card.value:

      player2.add_cards(player1_card)
      player2.add_cards(player2_card)

      print('p2>p1',player2)

    else:

      print('EQUAL')

      war_x = True
      inner_while = 0

      while war_x == True and game_status == True:  #we will make the players draw 3 cards if both cards are equal
        player1_list = []
        player2_list = []

        inner_while+=1
        print('Inner while loop count',inner_while)

        
        for i in range(3):

          if player1.all_cards != [] and player2.all_cards != []:

            player1_list.append(player1.remove_one())
            player2_list.append(player2.remove_one())

          elif player1.all_cards == [] or player2.all_cards == []:

            game_status = False

        print('player1_list',player1_list)
        print('player2_list',player2_list)
        
        if player1_list[-1].value > player2_list[-1].value:

          player1.add_cards(player1_list)
          player1.add_cards(player2_list)
          war_x = False

          

        elif player1_list[-1].value < player2_list[-1].value:

          player2.add_cards(player2_list)
          player2.add_cards(player1_list)
          war_x = False
        
        else: 
          war_x = True     



      
print(player1)
print(player2)

if len(player1.all_cards) == 0:
  print('Player 2 won')

elif len(player2.all_cards) == 0:
  print('Player 1 won')
