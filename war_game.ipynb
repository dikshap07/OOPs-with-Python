# %% [markdown]
# <a href="https://colab.research.google.com/github/dikshap07/OOPs-with-Python/blob/master/war_game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
 
suits = ['Hearts','Clubs','Spades','Diamonds']
 
ranks = ['Two','Three','Four','Five','Six','Seven','Eight','Nine','Ten','Jack','Queen','King','Ace']
 
values = {'Two': 2, 'Three': 3, 'Four': 4, 'Five': 5, 'Six' : 6 , 'Seven' :7, 'Eight': 8,'Nine':9,
          'Ten':10,'Jack':11, 'Queen': 12,'King': 13,'Ace':14 }


class Card():  
    
    
    def __init__(self,suit,rank):
        
        self.suit = suit
        self.rank = rank
        self.value = values[rank]
    
    #string method
    def __str__(self):
        
        return self.rank + ' of ' + self.suit 


class Deck():

  def __init__(self):

    self.all_cards = []  #list of objects

    for suit in suits:

      for rank in ranks:
        #create card object

        created_card = Card(suit,rank)

        self.all_cards.append(created_card)


  def shuffle(self):   #method to shuffle the card

    random.shuffle(self.all_cards)



  def deal_one(self):

    return self.all_cards.pop()  #we want the last card from deck




#player class

#used to hold a player's current list of cards
#player should be able to add or remove cards from their hands
#player shoyld be able to add single or mulitple cards to their list of card objects
class Player():

  def __init__(self,name):

    self.name  = name
    self.all_cards = []

  def remove_one(self):

    return self.all_cards.pop(0)    #to remove card from beginning of the list

    

  def add_cards(self,new_cards):


    if type(new_cards) == type([]):

      self.all_cards.extend(new_cards)

    else:

      self.all_cards.append(new_cards)

  def __str__(self):
    return f'Player {self.name} has {len(self.all_cards)} cards.'

# %% [markdown]
# #GAME LOGIC

# %%
#create 2 new instances of the player class

player1_name = input('Enter the name of Player1: ')

player2_name = input('Enter the name of Player2: ')

player1 = Player(player1_name)
player2 = Player(player2_name)
newdeck = Deck()
newdeck.shuffle()

#splitting the deck among the two players - alternate card from deck goes to each player respectively

for i in range(0,len(newdeck.all_cards)-1,2):  

  player1.add_cards(newdeck.all_cards[i])
  player2.add_cards(newdeck.all_cards[i+1])



print(player1)
print(player2)


game_status = True
    
round_num = 0
while game_status == True:

  round_num +=1
  print(f"Round {round_num}")


  if len(player1.all_cards) == 0:

    print('Player 1 out of cards'+ player2.name + 'Wins!')
    game_status = False
    break
  
  if len(player2.all_cards) == 0:

    print('Player 2 out of cards' + player1.name + 'Wins!')
    game_status = False
    break


  else:

     
    player1_cards = []
    
    player2_cards = []
    
    player1_cards.append(player1.remove_one())
    player2_cards.append(player2.remove_one())
    
    

    print(player1)
    print('')
    print(player2)


    at_war = True

    while at_war == True:


      if player1_cards[-1].value > player2_cards[-1].value:

        player1.add_cards(player1_cards)
        player1.add_cards(player2_cards)
        at_war = False
        break


      elif player2_cards[-1].value > player1_cards[-1].value:

        player2.add_cards(player1_cards)
        player2.add_cards(player2_cards)
        at_war = False
        break

      else:     

        print('WAR!!')
        if len(player1.all_cards) < 5:
            
          print('Player 2 won')

          game_status = False
          at_war = False
          
          break

        elif len(player2.all_cards) <5:

          print('Player 1 won')
          game_status = False
          at_war = False
          break

        if len(player1.all_cards) >= 5 and len(player2.all_cards) >= 5:

          for i in range(5):
            player1_cards.append(player1.remove_one())
            player2_cards.append(player2.remove_one())

          continue            

     


if len(player1.all_cards) == 0:
  print('Player 2 won')

elif len(player2.all_cards) == 0:
  print('Player 1 won')
# Out:
# Enter the name of Player1: r
# Enter the name of Player2: o
# Player r has 26 cards.
# Player o has 26 cards.
# Round 1
# Player r has 25 cards.
#
# Player o has 25 cards.
# Round 2
# Player r has 26 cards.
#
# Player o has 24 cards.
# Round 3
# Player r has 25 cards.
#
# Player o has 25 cards.
# Round 4
# Player r has 26 cards.
#
# Player o has 24 cards.
# Round 5
# Player r has 27 cards.
#
# Player o has 23 cards.
# Round 6
# Player r has 28 cards.
#
# Player o has 22 cards.
# Round 7
# Player r has 29 cards.
#
# Player o has 21 cards.
# Round 8
# Player r has 28 cards.
#
# Player o has 22 cards.
# Round 9
# Player r has 27 cards.
#
# Player o has 23 cards.
# Round 10
# Player r has 26 cards.
#
# Player o has 24 cards.
# Round 11
# Player r has 25 cards.
#
# Player o has 25 cards.
# Round 12
# Player r has 26 cards.
#
# Player o has 24 cards.
# WAR!!
# Round 13
# Player r has 32 cards.
#
# Player o has 18 cards.
# Round 14
# Player r has 31 cards.
#
# Player o has 19 cards.
# Round 15
# Player r has 30 cards.
#
# Player o has 20 cards.
# Round 16
# Player r has 31 cards.
#
# Player o has 19 cards.
# Round 17
# Player r has 32 cards.
#
# Player o has 18 cards.
# Round 18
# Player r has 31 cards.
#
# Player o has 19 cards.
# Round 19
# Player r has 30 cards.
#
# Player o has 20 cards.
# Round 20
# Player r has 31 cards.
#
# Player o has 19 cards.
# Round 21
# Player r has 30 cards.
#
# Player o has 20 cards.
# WAR!!
# Round 22
# Player r has 36 cards.
#
# Player o has 14 cards.
# Round 23
# Player r has 35 cards.
#
# Player o has 15 cards.
# Round 24
# Player r has 36 cards.
#
# Player o has 14 cards.
# Round 25
# Player r has 35 cards.
#
# Player o has 15 cards.
# Round 26
# Player r has 34 cards.
#
# Player o has 16 cards.
# Round 27
# Player r has 33 cards.
#
# Player o has 17 cards.
# Round 28
# Player r has 34 cards.
#
# Player o has 16 cards.
# Round 29
# Player r has 35 cards.
#
# Player o has 15 cards.
# Round 30
# Player r has 36 cards.
#
# Player o has 14 cards.
# Round 31
# Player r has 37 cards.
#
# Player o has 13 cards.
# Round 32
# Player r has 36 cards.
#
# Player o has 14 cards.
# Round 33
# Player r has 37 cards.
#
# Player o has 13 cards.
# Round 34
# Player r has 36 cards.
#
# Player o has 14 cards.
# Round 35
# Player r has 35 cards.
#
# Player o has 15 cards.
# Round 36
# Player r has 36 cards.
#
# Player o has 14 cards.
# Round 37
# Player r has 35 cards.
#
# Player o has 15 cards.
# Round 38
# Player r has 36 cards.
#
# Player o has 14 cards.
# WAR!!
# Round 39
# Player r has 42 cards.
#
# Player o has 8 cards.
# Round 40
# Player r has 43 cards.
#
# Player o has 7 cards.
# Round 41
# Player r has 44 cards.
#
# Player o has 6 cards.
# Round 42
# Player r has 43 cards.
#
# Player o has 7 cards.
# Round 43
# Player r has 44 cards.
#
# Player o has 6 cards.
# Round 44
# Player r has 45 cards.
#
# Player o has 5 cards.
# Round 45
# Player r has 46 cards.
#
# Player o has 4 cards.
# Round 46
# Player r has 45 cards.
#
# Player o has 5 cards.
# Round 47
# Player r has 46 cards.
#
# Player o has 4 cards.
# Round 48
# Player r has 47 cards.
#
# Player o has 3 cards.
# Round 49
# Player r has 46 cards.
#
# Player o has 4 cards.
# Round 50
# Player r has 45 cards.
#
# Player o has 5 cards.
# Round 51
# Player r has 44 cards.
#
# Player o has 6 cards.
# Round 52
# Player r has 43 cards.
#
# Player o has 7 cards.
# Round 53
# Player r has 44 cards.
#
# Player o has 6 cards.
# Round 54
# Player r has 43 cards.
#
# Player o has 7 cards.
# Round 55
# Player r has 44 cards.
#
# Player o has 6 cards.
# Round 56
# Player r has 43 cards.
#
# Player o has 7 cards.
# Round 57
# Player r has 44 cards.
#
# Player o has 6 cards.
# Round 58
# Player r has 43 cards.
#
# Player o has 7 cards.
# Round 59
# Player r has 44 cards.
#
# Player o has 6 cards.
# Round 60
# Player r has 43 cards.
#
# Player o has 7 cards.
# Round 61
# Player r has 44 cards.
#
# Player o has 6 cards.
# Round 62
# Player r has 43 cards.
#
# Player o has 7 cards.
# Round 63
# Player r has 44 cards.
#
# Player o has 6 cards.
# Round 64
# Player r has 43 cards.
#
# Player o has 7 cards.
# Round 65
# Player r has 44 cards.
#
# Player o has 6 cards.
# WAR!!
# Round 66
# Player r has 50 cards.
#
# Player o has 0 cards.
# Round 67
# Player r has 49 cards.
#
# Player o has 1 cards.
# Round 68
# Player r has 48 cards.
#
# Player o has 2 cards.
# WAR!!
# Player 1 won

# %% [markdown]
# #GAMELOGIC - MY METHOD

# %%
#create 2 new instances of the player class
player1_name = input('Enter the name of Player1: ')

player2_name = input('Enter the name of Player2: ')

player1 = Player(player1_name)
player2 = Player(player2_name)
newdeck = Deck()
newdeck.shuffle()


#splitting the deck among the two players - alternate card from deck goes to each player respectively

for i in range(0,len(newdeck.all_cards)-1,2):
  player1.add_cards(newdeck.all_cards[i])
  player2.add_cards(newdeck.all_cards[i+1])

# for x in range(26):

#   player1.add_cards(newdeck.deal_one())
#   player2.add_cards(newdeck.deal_one())

print(player1)
print(player2)


game_status = True
    
round_num = 0
while game_status == True:

  round_num +=1

  if round_num > 1000:
    random.shuffle(player1.all_cards)
    random.shuffle(player2.all_cards)
  print('')
  print(f"Round {round_num}")


  if len(player1.all_cards) == 0:

    print('Player 1 out of cards'+ player2.name + 'Wins!')
    game_status = False
    break
  
  if len(player2.all_cards) == 0:

    print('Player 2 out of cards' + player1.name + 'Wins!')
    game_status = False
    break


  else:
    print('')
    print(player1)
    print('')
    print(player2)
     
    player_cards = []
    player1_card = player1.remove_one()
    player2_card = player2.remove_one()
    player_cards.append(player1_card)
    player_cards.append(player2_card)
    
    


    print('player1_card_value: ',player1_card.value)
    print('')
    print('player2_card_value: ',player2_card.value)   


    at_war = True

    

    if player1_card.value == player2_card.value:  
      print('')
      print('!!!!AT WARRR!!!!')

      while at_war == True:
        player1_list = []
        player2_list = []   
        #player_cards = []    

        if len(player1.all_cards) < 5:
            
          print('Player 1 doesnt hve enough cards Player 2 won')

          game_status = False
          at_war = False
          
          break

        elif len(player2.all_cards) <5:

          print('Player 2 doesnt hve enough cards Player 1 won')
          game_status = False
          at_war = False
          break

        if len(player1.all_cards) >= 5 and len(player2.all_cards) >= 5:

          for i in range(5):
            player1_list.append(player1.remove_one())
            player2_list.append(player2.remove_one())


          player_cards.extend(player1_list)
          player_cards.extend(player2_list)
          print('')
          print("CARD LIST LEN", len(player_cards))

          if player1_list[-1].value > player2_list[-1].value:

            print('player1 card value',player1_list[-1].value)
            print('player2 card value',player2_list[-1].value)

            print('player 1 card has more value in war')

            player1.add_cards(player_cards)
            print('')
            print(player1)
            at_war = False
            break

          


          elif player1_list[-1].value < player2_list[-1].value:

            print('player1 card value',player1_list[-1].value)
            print('player2 card value',player2_list[-1].value)


            print('player 2 card has more value')

            player2.add_cards(player_cards)
            print('')
            print(player2)
           #player2.add_cards(player1_list)
            at_war = False
            break

      


    elif player1_card.value > player2_card.value:

      print('len of player_cards: ', len(player_cards))
      print(player_cards)
      player1.add_cards(player_cards)

      print('no of cards with player1 as he won',player1)
      print('')
      print('no of cards with player2 as he lost',player2)
      #player1.add_cards(player2_cards)

      #print('p1>p2', player1)

    elif player2_card.value > player1_card.value:

      print('len of player_cards: ', len(player_cards))

      player2.add_cards(player_cards)
      print('no of cards with player2 as he won',player2)
      print('')
      print('no of cards with player1 as he lost',player1)
# Out:
# Enter the name of Player1: rick
# Enter the name of Player2: morty
# Player rick has 26 cards.
# Player morty has 26 cards.
#
# Round 1
#
# Player rick has 26 cards.
#
# Player morty has 26 cards.
# player1_card_value:  13
#
# player2_card_value:  2
# len of player_cards:  2
# [<__main__.Card object at 0x7fccde295690>, <__main__.Card object at 0x7fccde295b10>]
# no of cards with player1 as he won Player rick has 27 cards.
#
# no of cards with player2 as he lost Player morty has 25 cards.
#
# Round 2
#
# Player rick has 27 cards.
#
# Player morty has 25 cards.
# player1_card_value:  10
#
# player2_card_value:  8
# len of player_cards:  2
# [<__main__.Card object at 0x7fccde295850>, <__main__.Card object at 0x7fccde295990>]
# no of cards with player1 as he won Player rick has 28 cards.
#
# no of cards with player2 as he lost Player morty has 24 cards.
#
# Round 3
#
# Player rick has 28 cards.
#
# Player morty has 24 cards.
# player1_card_value:  11
#
# player2_card_value:  9
# len of player_cards:  2
# [<__main__.Card object at 0x7fccde295090>, <__main__.Card object at 0x7fccde295d90>]
# no of cards with player1 as he won Player rick has 29 cards.
#
# no of cards with player2 as he lost Player morty has 23 cards.
#
# Round 4
#
# Player rick has 29 cards.
#
# Player morty has 23 cards.
# player1_card_value:  8
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 24 cards.
#
# no of cards with player1 as he lost Player rick has 28 cards.
#
# Round 5
#
# Player rick has 28 cards.
#
# Player morty has 24 cards.
# player1_card_value:  7
#
# player2_card_value:  11
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 25 cards.
#
# no of cards with player1 as he lost Player rick has 27 cards.
#
# Round 6
#
# Player rick has 27 cards.
#
# Player morty has 25 cards.
# player1_card_value:  6
#
# player2_card_value:  5
# len of player_cards:  2
# [<__main__.Card object at 0x7fccde295e10>, <__main__.Card object at 0x7fccde295050>]
# no of cards with player1 as he won Player rick has 28 cards.
#
# no of cards with player2 as he lost Player morty has 24 cards.
#
# Round 7
#
# Player rick has 28 cards.
#
# Player morty has 24 cards.
# player1_card_value:  6
#
# player2_card_value:  5
# len of player_cards:  2
# [<__main__.Card object at 0x7fccde295950>, <__main__.Card object at 0x7fccde251d10>]
# no of cards with player1 as he won Player rick has 29 cards.
#
# no of cards with player2 as he lost Player morty has 23 cards.
#
# Round 8
#
# Player rick has 29 cards.
#
# Player morty has 23 cards.
# player1_card_value:  14
#
# player2_card_value:  6
# len of player_cards:  2
# [<__main__.Card object at 0x7fccde295590>, <__main__.Card object at 0x7fccde2955d0>]
# no of cards with player1 as he won Player rick has 30 cards.
#
# no of cards with player2 as he lost Player morty has 22 cards.
#
# Round 9
#
# Player rick has 30 cards.
#
# Player morty has 22 cards.
# player1_card_value:  10
#
# player2_card_value:  14
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 23 cards.
#
# no of cards with player1 as he lost Player rick has 29 cards.
#
# Round 10
#
# Player rick has 29 cards.
#
# Player morty has 23 cards.
# player1_card_value:  12
#
# player2_card_value:  11
# len of player_cards:  2
# [<__main__.Card object at 0x7fccde295f10>, <__main__.Card object at 0x7fccde295a50>]
# no of cards with player1 as he won Player rick has 30 cards.
#
# no of cards with player2 as he lost Player morty has 22 cards.
#
# Round 11
#
# Player rick has 30 cards.
#
# Player morty has 22 cards.
# player1_card_value:  2
#
# player2_card_value:  2
#
# !!!!AT WARRR!!!!
#
# CARD LIST LEN 12
#
# CARD LIST LEN 22
# player1 card value 8
# player2 card value 5
# player 1 card has more value in war
#
# Player rick has 41 cards.
#
# Round 12
#
# Player rick has 41 cards.
#
# Player morty has 11 cards.
# player1_card_value:  12
#
# player2_card_value:  10
# len of player_cards:  2
# [<__main__.Card object at 0x7fccde295450>, <__main__.Card object at 0x7fccde295750>]
# no of cards with player1 as he won Player rick has 42 cards.
#
# no of cards with player2 as he lost Player morty has 10 cards.
#
# Round 13
#
# Player rick has 42 cards.
#
# Player morty has 10 cards.
# player1_card_value:  3
#
# player2_card_value:  11
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 11 cards.
#
# no of cards with player1 as he lost Player rick has 41 cards.
#
# Round 14
#
# Player rick has 41 cards.
#
# Player morty has 11 cards.
# player1_card_value:  4
#
# player2_card_value:  13
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 12 cards.
#
# no of cards with player1 as he lost Player rick has 40 cards.
#
# Round 15
#
# Player rick has 40 cards.
#
# Player morty has 12 cards.
# player1_card_value:  5
#
# player2_card_value:  9
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 13 cards.
#
# no of cards with player1 as he lost Player rick has 39 cards.
#
# Round 16
#
# Player rick has 39 cards.
#
# Player morty has 13 cards.
# player1_card_value:  8
#
# player2_card_value:  4
# len of player_cards:  2
# [<__main__.Card object at 0x7fccde295150>, <__main__.Card object at 0x7fccde295d50>]
# no of cards with player1 as he won Player rick has 40 cards.
#
# no of cards with player2 as he lost Player morty has 12 cards.
#
# Round 17
#
# Player rick has 40 cards.
#
# Player morty has 12 cards.
# player1_card_value:  13
#
# player2_card_value:  8
# len of player_cards:  2
# [<__main__.Card object at 0x7fccde295690>, <__main__.Card object at 0x7fccde295ed0>]
# no of cards with player1 as he won Player rick has 41 cards.
#
# no of cards with player2 as he lost Player morty has 11 cards.
#
# Round 18
#
# Player rick has 41 cards.
#
# Player morty has 11 cards.
# player1_card_value:  2
#
# player2_card_value:  10
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 12 cards.
#
# no of cards with player1 as he lost Player rick has 40 cards.
#
# Round 19
#
# Player rick has 40 cards.
#
# Player morty has 12 cards.
# player1_card_value:  10
#
# player2_card_value:  7
# len of player_cards:  2
# [<__main__.Card object at 0x7fccde295850>, <__main__.Card object at 0x7fccde295810>]
# no of cards with player1 as he won Player rick has 41 cards.
#
# no of cards with player2 as he lost Player morty has 11 cards.
#
# Round 20
#
# Player rick has 41 cards.
#
# Player morty has 11 cards.
# player1_card_value:  8
#
# player2_card_value:  11
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 12 cards.
#
# no of cards with player1 as he lost Player rick has 40 cards.
#
# Round 21
#
# Player rick has 40 cards.
#
# Player morty has 12 cards.
# player1_card_value:  11
#
# player2_card_value:  10
# len of player_cards:  2
# [<__main__.Card object at 0x7fccde295090>, <__main__.Card object at 0x7fccde2950d0>]
# no of cards with player1 as he won Player rick has 41 cards.
#
# no of cards with player2 as he lost Player morty has 11 cards.
#
# Round 22
#
# Player rick has 41 cards.
#
# Player morty has 11 cards.
# player1_card_value:  9
#
# player2_card_value:  14
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 12 cards.
#
# no of cards with player1 as he lost Player rick has 40 cards.
#
# Round 23
#
# Player rick has 40 cards.
#
# Player morty has 12 cards.
# player1_card_value:  6
#
# player2_card_value:  3
# len of player_cards:  2
# [<__main__.Card object at 0x7fccde295e10>, <__main__.Card object at 0x7fccde2491d0>]
# no of cards with player1 as he won Player rick has 41 cards.
#
# no of cards with player2 as he lost Player morty has 11 cards.
#
# Round 24
#
# Player rick has 41 cards.
#
# Player morty has 11 cards.
# player1_card_value:  5
#
# player2_card_value:  11
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 12 cards.
#
# no of cards with player1 as he lost Player rick has 40 cards.
#
# Round 25
#
# Player rick has 40 cards.
#
# Player morty has 12 cards.
# player1_card_value:  6
#
# player2_card_value:  4
# len of player_cards:  2
# [<__main__.Card object at 0x7fccde295950>, <__main__.Card object at 0x7fccde295a10>]
# no of cards with player1 as he won Player rick has 41 cards.
#
# no of cards with player2 as he lost Player morty has 11 cards.
#
# Round 26
#
# Player rick has 41 cards.
#
# Player morty has 11 cards.
# player1_card_value:  5
#
# player2_card_value:  13
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 12 cards.
#
# no of cards with player1 as he lost Player rick has 40 cards.
#
# Round 27
#
# Player rick has 40 cards.
#
# Player morty has 12 cards.
# player1_card_value:  14
#
# player2_card_value:  5
# len of player_cards:  2
# [<__main__.Card object at 0x7fccde295590>, <__main__.Card object at 0x7fccde295650>]
# no of cards with player1 as he won Player rick has 41 cards.
#
# no of cards with player2 as he lost Player morty has 11 cards.
#
# Round 28
#
# Player rick has 41 cards.
#
# Player morty has 11 cards.
# player1_card_value:  6
#
# player2_card_value:  9
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 12 cards.
#
# no of cards with player1 as he lost Player rick has 40 cards.
#
# Round 29
#
# Player rick has 40 cards.
#
# Player morty has 12 cards.
# player1_card_value:  12
#
# player2_card_value:  2
# len of player_cards:  2
# [<__main__.Card object at 0x7fccde295f10>, <__main__.Card object at 0x7fccde295b10>]
# no of cards with player1 as he won Player rick has 41 cards.
#
# no of cards with player2 as he lost Player morty has 11 cards.
#
# Round 30
#
# Player rick has 41 cards.
#
# Player morty has 11 cards.
# player1_card_value:  11
#
# player2_card_value:  10
# len of player_cards:  2
# [<__main__.Card object at 0x7fccde295a50>, <__main__.Card object at 0x7fccde2956d0>]
# no of cards with player1 as he won Player rick has 42 cards.
#
# no of cards with player2 as he lost Player morty has 10 cards.
#
# Round 31
#
# Player rick has 42 cards.
#
# Player morty has 10 cards.
# player1_card_value:  2
#
# player2_card_value:  8
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 11 cards.
#
# no of cards with player1 as he lost Player rick has 41 cards.
#
# Round 32
#
# Player rick has 41 cards.
#
# Player morty has 11 cards.
# player1_card_value:  2
#
# player2_card_value:  11
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 12 cards.
#
# no of cards with player1 as he lost Player rick has 40 cards.
#
# Round 33
#
# Player rick has 40 cards.
#
# Player morty has 12 cards.
# player1_card_value:  3
#
# player2_card_value:  9
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 13 cards.
#
# no of cards with player1 as he lost Player rick has 39 cards.
#
# Round 34
#
# Player rick has 39 cards.
#
# Player morty has 13 cards.
# player1_card_value:  4
#
# player2_card_value:  14
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 14 cards.
#
# no of cards with player1 as he lost Player rick has 38 cards.
#
# Round 35
#
# Player rick has 38 cards.
#
# Player morty has 14 cards.
# player1_card_value:  12
#
# player2_card_value:  5
# len of player_cards:  2
# [<__main__.Card object at 0x7fccde295910>, <__main__.Card object at 0x7fccde295050>]
# no of cards with player1 as he won Player rick has 39 cards.
#
# no of cards with player2 as he lost Player morty has 13 cards.
#
# Round 36
#
# Player rick has 39 cards.
#
# Player morty has 13 cards.
# player1_card_value:  14
#
# player2_card_value:  11
# len of player_cards:  2
# [<__main__.Card object at 0x7fccde295550>, <__main__.Card object at 0x7fccde295e50>]
# no of cards with player1 as he won Player rick has 40 cards.
#
# no of cards with player2 as he lost Player morty has 12 cards.
#
# Round 37
#
# Player rick has 40 cards.
#
# Player morty has 12 cards.
# player1_card_value:  9
#
# player2_card_value:  5
# len of player_cards:  2
# [<__main__.Card object at 0x7fccde295fd0>, <__main__.Card object at 0x7fccde251d10>]
# no of cards with player1 as he won Player rick has 41 cards.
#
# no of cards with player2 as he lost Player morty has 11 cards.
#
# Round 38
#
# Player rick has 41 cards.
#
# Player morty has 11 cards.
# player1_card_value:  7
#
# player2_card_value:  13
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 12 cards.
#
# no of cards with player1 as he lost Player rick has 40 cards.
#
# Round 39
#
# Player rick has 40 cards.
#
# Player morty has 12 cards.
# player1_card_value:  13
#
# player2_card_value:  6
# len of player_cards:  2
# [<__main__.Card object at 0x7fccde295b90>, <__main__.Card object at 0x7fccde2955d0>]
# no of cards with player1 as he won Player rick has 41 cards.
#
# no of cards with player2 as he lost Player morty has 11 cards.
#
# Round 40
#
# Player rick has 41 cards.
#
# Player morty has 11 cards.
# player1_card_value:  6
#
# player2_card_value:  9
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 12 cards.
#
# no of cards with player1 as he lost Player rick has 40 cards.
#
# Round 41
#
# Player rick has 40 cards.
#
# Player morty has 12 cards.
# player1_card_value:  13
#
# player2_card_value:  2
# len of player_cards:  2
# [<__main__.Card object at 0x7fccde295710>, <__main__.Card object at 0x7fcce1d9fd50>]
# no of cards with player1 as he won Player rick has 41 cards.
#
# no of cards with player2 as he lost Player morty has 11 cards.
#
# Round 42
#
# Player rick has 41 cards.
#
# Player morty has 11 cards.
# player1_card_value:  9
#
# player2_card_value:  8
# len of player_cards:  2
# [<__main__.Card object at 0x7fccde295110>, <__main__.Card object at 0x7fccde295990>]
# no of cards with player1 as he won Player rick has 42 cards.
#
# no of cards with player2 as he lost Player morty has 10 cards.
#
# Round 43
#
# Player rick has 42 cards.
#
# Player morty has 10 cards.
# player1_card_value:  7
#
# player2_card_value:  2
# len of player_cards:  2
# [<__main__.Card object at 0x7fccde295790>, <__main__.Card object at 0x7fccde295350>]
# no of cards with player1 as he won Player rick has 43 cards.
#
# no of cards with player2 as he lost Player morty has 9 cards.
#
# Round 44
#
# Player rick has 43 cards.
#
# Player morty has 9 cards.
# player1_card_value:  7
#
# player2_card_value:  11
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 10 cards.
#
# no of cards with player1 as he lost Player rick has 42 cards.
#
# Round 45
#
# Player rick has 42 cards.
#
# Player morty has 10 cards.
# player1_card_value:  2
#
# player2_card_value:  3
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 11 cards.
#
# no of cards with player1 as he lost Player rick has 41 cards.
#
# Round 46
#
# Player rick has 41 cards.
#
# Player morty has 11 cards.
# player1_card_value:  3
#
# player2_card_value:  9
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 12 cards.
#
# no of cards with player1 as he lost Player rick has 40 cards.
#
# Round 47
#
# Player rick has 40 cards.
#
# Player morty has 12 cards.
# player1_card_value:  8
#
# player2_card_value:  4
# len of player_cards:  2
# [<__main__.Card object at 0x7fccde295310>, <__main__.Card object at 0x7fccde295c10>]
# no of cards with player1 as he won Player rick has 41 cards.
#
# no of cards with player2 as he lost Player morty has 11 cards.
#
# Round 48
#
# Player rick has 41 cards.
#
# Player morty has 11 cards.
# player1_card_value:  14
#
# player2_card_value:  14
#
# !!!!AT WARRR!!!!
#
# CARD LIST LEN 12
# player1 card value 12
# player2 card value 7
# player 1 card has more value in war
#
# Player rick has 47 cards.
#
# Round 49
#
# Player rick has 47 cards.
#
# Player morty has 5 cards.
# player1_card_value:  10
#
# player2_card_value:  11
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 6 cards.
#
# no of cards with player1 as he lost Player rick has 46 cards.
#
# Round 50
#
# Player rick has 46 cards.
#
# Player morty has 6 cards.
# player1_card_value:  8
#
# player2_card_value:  2
# len of player_cards:  2
# [<__main__.Card object at 0x7fccde295150>, <__main__.Card object at 0x7fccde295d10>]
# no of cards with player1 as he won Player rick has 47 cards.
#
# no of cards with player2 as he lost Player morty has 5 cards.
#
# Round 51
#
# Player rick has 47 cards.
#
# Player morty has 5 cards.
# player1_card_value:  4
#
# player2_card_value:  3
# len of player_cards:  2
# [<__main__.Card object at 0x7fccde295d50>, <__main__.Card object at 0x7fccde2954d0>]
# no of cards with player1 as he won Player rick has 48 cards.
#
# no of cards with player2 as he lost Player morty has 4 cards.
#
# Round 52
#
# Player rick has 48 cards.
#
# Player morty has 4 cards.
# player1_card_value:  13
#
# player2_card_value:  3
# len of player_cards:  2
# [<__main__.Card object at 0x7fccde295690>, <__main__.Card object at 0x7fccde295e90>]
# no of cards with player1 as he won Player rick has 49 cards.
#
# no of cards with player2 as he lost Player morty has 3 cards.
#
# Round 53
#
# Player rick has 49 cards.
#
# Player morty has 3 cards.
# player1_card_value:  8
#
# player2_card_value:  9
# len of player_cards:  2
# no of cards with player2 as he won Player morty has 4 cards.
#
# no of cards with player1 as he lost Player rick has 48 cards.
#
# Round 54
#
# Player rick has 48 cards.
#
# Player morty has 4 cards.
# player1_card_value:  10
#
# player2_card_value:  10
#
# !!!!AT WARRR!!!!
# Player 2 doesnt hve enough cards Player 1 won
